# %% [markdown]
# # AlphaNetPro

# %% [markdown]
# ## Import packages

# %%
import tensorflow.compat.v1 as tf
import tensorflow.keras as keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import shap

from tensorflow.keras import models, layers
from tensorflow.keras import backend as K
from itertools import combinations

import functools

# %%
tf.__version__
# Out:
# '2.5.0'

# %%
shap.__version__
# Out:
# '0.39.0'

# %%
from tensorflow.compat.v1.keras.backend import get_session
tf.compat.v1.disable_v2_behavior()

shap.initjs()
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# ## Create synthetic data

# %% [markdown]
# **Note**: This step can be skipped since the real data is now available

# %%
# ndays = 300  # Number of days
# nfeats = 5   # Number of features

# raw_data = dict()
# maxlen = len(str(ndays - 1))
# for i in range(ndays):
#     key = 'T' + f'{i}'.zfill(maxlen)
#     raw_data[key] = np.random.random(nfeats)
# features = [f'F{i}' for i in range(nfeats)]

# df = pd.DataFrame(raw_data, index=features)

# %%
# df

# %% [markdown]
# ## Import Data

# %%
inputfname = './SSE50_data.csv'
df = pd.read_csv(inputfname, index_col='Date')
features = df.columns

# %%
features.values
# Out:
# array(['Open', 'High', 'Low', 'Close', 'Volume', 'Amount', 'MA10',
#        'SMA10', 'EMA10', 'WMA10', 'RSI10', 'VWAP10'], dtype=object)

# %%
df = df.T
df
# Out:
# Date         1/19/10       1/20/10       1/21/10       1/22/10       1/25/10  \
# Open    2.424469e+03  2.436647e+03  2.362597e+03  2.344973e+03  2.355357e+03
# High    2.450281e+03  2.439468e+03  2.391508e+03  2.398989e+03  2.389627e+03
# Low     2.424161e+03  2.356161e+03  2.346148e+03  2.317481e+03  2.350009e+03
# Close   2.432713e+03  2.359485e+03  2.377753e+03  2.380055e+03  2.353471e+03
# Volume  2.782908e+09  3.474848e+09  2.919615e+09  4.063927e+09  2.074988e+09
# Amount  3.754464e+10  4.572057e+10  3.780439e+10  4.904208e+10  2.643013e+10
# MA10    2.464619e+03  2.453491e+03  2.438038e+03  2.429437e+03  2.420826e+03
# SMA10   2.438955e+03  2.436236e+03  2.411791e+03  2.401647e+03  2.395527e+03
# EMA10   2.466464e+03  2.447013e+03  2.434421e+03  2.424536e+03  2.411615e+03
# WMA10   2.445673e+03  2.439872e+03  2.422781e+03  2.411820e+03  2.402841e+03
# RSI10   5.735696e+01  2.114056e+01  1.332092e+01  3.635668e+01  4.737532e+01
# VWAP10  2.468900e+03  2.462053e+03  2.456259e+03  2.448815e+03  2.445420e+03
#
# Date         1/26/10       1/27/10       1/28/10       1/29/10        2/1/10  \
# Open    2.354905e+03  2.313007e+03  2.263061e+03  2.241117e+03  2.238617e+03
# High    2.363411e+03  2.319993e+03  2.267853e+03  2.276767e+03  2.238898e+03
# Low     2.296875e+03  2.260564e+03  2.235603e+03  2.231649e+03  2.182952e+03
# Close   2.311447e+03  2.264605e+03  2.252610e+03  2.243994e+03  2.208936e+03
# Volume  2.470038e+09  2.228021e+09  1.902346e+09  1.862604e+09  2.208244e+09
# Amount  3.034774e+10  2.728837e+10  2.375429e+10  2.386174e+10  2.860821e+10
# MA10    2.408292e+03  2.388633e+03  2.375130e+03  2.358113e+03  2.339732e+03
# SMA10   2.383736e+03  2.358987e+03  2.331326e+03  2.307853e+03  2.288509e+03
# EMA10   2.393403e+03  2.369985e+03  2.348644e+03  2.329617e+03  2.307675e+03
# WMA10   2.390595e+03  2.372986e+03  2.350436e+03  2.328160e+03  2.307411e+03
# RSI10   5.370132e+01  6.007584e+00  4.223217e+01  1.999395e+01  8.800863e+00
# VWAP10  2.439871e+03  2.433615e+03  2.427681e+03  2.422197e+03  2.414684e+03
#
# Date    ...       5/19/21       5/20/21       5/21/21       5/24/21  \
# Open    ...  3.531788e+03  3.514428e+03  3.532872e+03  3.482993e+03
# High    ...  3.531788e+03  3.530491e+03  3.544266e+03  3.499445e+03
# Low     ...  3.501383e+03  3.496520e+03  3.475263e+03  3.457292e+03
# Close   ...  3.511467e+03  3.522451e+03  3.481862e+03  3.497747e+03
# Volume  ...  2.380663e+09  2.382720e+09  2.064464e+09  2.298654e+09
# Amount  ...  6.055228e+10  6.320845e+10  6.117673e+10  6.453227e+10
# MA10    ...  3.462753e+03  3.464781e+03  3.472032e+03  3.479588e+03
# SMA10   ...  3.497314e+03  3.500395e+03  3.505779e+03  3.498425e+03
# EMA10   ...  3.488784e+03  3.494905e+03  3.492534e+03  3.493481e+03
# WMA10   ...  3.477152e+03  3.486009e+03  3.496495e+03  3.498282e+03
# RSI10   ...  4.417165e+01  3.424691e+01  3.554701e+01  5.042196e+01
# VWAP10  ...  2.488085e+03  2.488332e+03  2.488542e+03  2.488773e+03
#
# Date         5/25/21       5/26/21       5/27/21       5/28/21       5/31/21  \
# Open    3.505814e+03  3.656340e+03  3.645482e+03  3.663875e+03  3.652888e+03
# High    3.645075e+03  3.678067e+03  3.709002e+03  3.689248e+03  3.652892e+03
# Low     3.505626e+03  3.643985e+03  3.628960e+03  3.630574e+03  3.615423e+03
# Close   3.641292e+03  3.657190e+03  3.664942e+03  3.659296e+03  3.650224e+03
# Volume  4.418286e+09  3.455940e+09  2.987912e+09  2.868285e+09  2.632840e+09
# Amount  1.257360e+11  9.658566e+10  8.514700e+10  8.046883e+10  7.791793e+10
# MA10    3.489364e+03  3.509722e+03  3.530654e+03  3.555760e+03  3.571386e+03
# SMA10   3.499288e+03  3.542176e+03  3.575720e+03  3.605005e+03  3.622334e+03
# EMA10   3.520356e+03  3.545235e+03  3.567000e+03  3.583781e+03  3.595862e+03
# WMA10   3.501584e+03  3.529207e+03  3.556019e+03  3.580435e+03  3.599260e+03
# RSI10   7.691983e+01  8.019945e+01  5.542548e+01  9.255655e+01  8.680492e+01
# VWAP10  2.489265e+03  2.489672e+03  2.490026e+03  2.490363e+03  2.490667e+03
#
# Date          6/1/21
# Open    3.641969e+03
# High    3.652948e+03
# Low     3.608204e+03
# Close   3.650903e+03
# Volume  2.816155e+09
# Amount  8.285057e+10
# MA10    3.582417e+03
# SMA10   3.630638e+03
# EMA10   3.605869e+03
# WMA10   3.613594e+03
# RSI10   6.949776e+01
# VWAP10  2.490991e+03
#
# [12 rows x 2761 columns]

# %% [markdown]
# ## Function to Generate Samples

# %%
# rtdays=5 means the target value would be the 5-day return
def generate_samples(data, rtdays=5, width=30, strides=1):
    dates = []
    samples = []
    targets = []
    
    i = data.shape[1] - 1 - rtdays
    
    while i - width + 1 >= 0:
        rt = (data.iloc[3,i+rtdays] - data.iloc[3,i]) / data.iloc[3,i]
        
        dates.append(data.columns[i])
        samples.append(data.iloc[:,i-width+1:i+1])
        targets.append(rt)
        
        i -= strides
    
    dates.reverse()
    samples.reverse()
    targets.reverse()
    
    return dates, samples, targets

# %%
dates, samples, targets = generate_samples(df, strides=2)

# %%
len(dates)
# Out:
# 1364

# %%
len(samples)
# Out:
# 1364

# %%
len(targets)
# Out:
# 1364

# %%
dates[:10]
# Out:
# ['3/8/10',
#  '3/10/10',
#  '3/12/10',
#  '3/16/10',
#  '3/18/10',
#  '3/22/10',
#  '3/24/10',
#  '3/26/10',
#  '3/30/10',
#  '4/1/10']

# %%
dates[-10:]
# Out:
# ['4/26/21',
#  '4/28/21',
#  '4/30/21',
#  '5/7/21',
#  '5/11/21',
#  '5/13/21',
#  '5/17/21',
#  '5/19/21',
#  '5/21/21',
#  '5/25/21']

# %%
samples[0]
# Out:
# Date         1/19/10       1/20/10       1/21/10       1/22/10       1/25/10  \
# Open    2.424469e+03  2.436647e+03  2.362597e+03  2.344973e+03  2.355357e+03
# High    2.450281e+03  2.439468e+03  2.391508e+03  2.398989e+03  2.389627e+03
# Low     2.424161e+03  2.356161e+03  2.346148e+03  2.317481e+03  2.350009e+03
# Close   2.432713e+03  2.359485e+03  2.377753e+03  2.380055e+03  2.353471e+03
# Volume  2.782908e+09  3.474848e+09  2.919615e+09  4.063927e+09  2.074988e+09
# Amount  3.754464e+10  4.572057e+10  3.780439e+10  4.904208e+10  2.643013e+10
# MA10    2.464619e+03  2.453491e+03  2.438038e+03  2.429437e+03  2.420826e+03
# SMA10   2.438955e+03  2.436236e+03  2.411791e+03  2.401647e+03  2.395527e+03
# EMA10   2.466464e+03  2.447013e+03  2.434421e+03  2.424536e+03  2.411615e+03
# WMA10   2.445673e+03  2.439872e+03  2.422781e+03  2.411820e+03  2.402841e+03
# RSI10   5.735696e+01  2.114056e+01  1.332092e+01  3.635668e+01  4.737532e+01
# VWAP10  2.468900e+03  2.462053e+03  2.456259e+03  2.448815e+03  2.445420e+03
#
# Date         1/26/10       1/27/10       1/28/10       1/29/10        2/1/10  \
# Open    2.354905e+03  2.313007e+03  2.263061e+03  2.241117e+03  2.238617e+03
# High    2.363411e+03  2.319993e+03  2.267853e+03  2.276767e+03  2.238898e+03
# Low     2.296875e+03  2.260564e+03  2.235603e+03  2.231649e+03  2.182952e+03
# Close   2.311447e+03  2.264605e+03  2.252610e+03  2.243994e+03  2.208936e+03
# Volume  2.470038e+09  2.228021e+09  1.902346e+09  1.862604e+09  2.208244e+09
# Amount  3.034774e+10  2.728837e+10  2.375429e+10  2.386174e+10  2.860821e+10
# MA10    2.408292e+03  2.388633e+03  2.375130e+03  2.358113e+03  2.339732e+03
# SMA10   2.383736e+03  2.358987e+03  2.331326e+03  2.307853e+03  2.288509e+03
# EMA10   2.393403e+03  2.369985e+03  2.348644e+03  2.329617e+03  2.307675e+03
# WMA10   2.390595e+03  2.372986e+03  2.350436e+03  2.328160e+03  2.307411e+03
# RSI10   5.370132e+01  6.007584e+00  4.223217e+01  1.999395e+01  8.800863e+00
# VWAP10  2.439871e+03  2.433615e+03  2.427681e+03  2.422197e+03  2.414684e+03
#
# Date    ...       2/23/10       2/24/10       2/25/10       2/26/10  \
# Open    ...  2.261993e+03  2.211393e+03  2.254801e+03  2.278432e+03
# High    ...  2.261993e+03  2.252645e+03  2.286920e+03  2.288597e+03
# Low     ...  2.202214e+03  2.204675e+03  2.251963e+03  2.270769e+03
# Close   ...  2.227952e+03  2.251700e+03  2.282640e+03  2.274325e+03
# Volume  ...  1.527640e+09  1.681535e+09  2.418678e+09  1.527406e+09
# Amount  ...  2.528608e+10  2.125730e+10  3.221489e+10  1.940044e+10
# MA10    ...  2.249152e+03  2.250544e+03  2.247934e+03  2.250062e+03
# SMA10   ...  2.260955e+03  2.252856e+03  2.252044e+03  2.260044e+03
# EMA10   ...  2.257167e+03  2.256173e+03  2.260985e+03  2.263411e+03
# WMA10   ...  2.255508e+03  2.251654e+03  2.251864e+03  2.258174e+03
# RSI10   ...  6.714682e+01  7.747043e+01  3.378598e+01  3.070260e+01
# VWAP10  ...  2.378477e+03  2.375523e+03  2.372571e+03  2.370867e+03
#
# Date          3/1/10        3/2/10        3/3/10        3/4/10        3/5/10  \
# Open    2.282338e+03  2.312492e+03  2.304056e+03  2.312299e+03  2.264678e+03
# High    2.316384e+03  2.320312e+03  2.312419e+03  2.312783e+03  2.276763e+03
# Low     2.281699e+03  2.293917e+03  2.287037e+03  2.259176e+03  2.258962e+03
# Close   2.311075e+03  2.302185e+03  2.311841e+03  2.261926e+03  2.267939e+03
# Volume  1.931268e+09  1.521234e+09  1.584585e+09  1.962072e+09  1.334754e+09
# Amount  2.559932e+10  2.030428e+10  2.113852e+10  2.426704e+10  1.680636e+10
# MA10    2.255535e+03  2.265529e+03  2.272844e+03  2.278029e+03  2.277707e+03
# SMA10   2.264089e+03  2.278690e+03  2.286613e+03  2.294327e+03  2.285150e+03
# EMA10   2.272077e+03  2.277551e+03  2.283786e+03  2.279811e+03  2.277653e+03
# WMA10   2.262586e+03  2.272684e+03  2.279349e+03  2.286439e+03  2.283511e+03
# RSI10   5.077725e+01  8.004455e+01  8.082813e+01  7.022435e+01  6.134003e+01
# VWAP10  2.369357e+03  2.368257e+03  2.367120e+03  2.365215e+03  2.363821e+03
#
# Date          3/8/10
# Open    2.272607e+03
# High    2.290091e+03
# Low     2.265195e+03
# Close   2.284682e+03
# Volume  1.237555e+09
# Amount  1.548105e+10
# MA10    2.276063e+03
# SMA10   2.279554e+03
# EMA10   2.278931e+03
# WMA10   2.281735e+03
# RSI10   3.300821e+01
# VWAP10  2.362722e+03
#
# [12 rows x 30 columns]

# %%
samples[-1]
# Out:
# Date          4/9/21       4/12/21       4/13/21       4/14/21       4/15/21  \
# Open    3.564657e+03  3.505714e+03  3.483013e+03  3.469396e+03  3.456548e+03
# High    3.565222e+03  3.520734e+03  3.505390e+03  3.484057e+03  3.456548e+03
# Low     3.504494e+03  3.465655e+03  3.448568e+03  3.442234e+03  3.399761e+03
# Close   3.514111e+03  3.477065e+03  3.461459e+03  3.469173e+03  3.431493e+03
# Volume  1.968586e+09  2.485501e+09  2.107433e+09  1.950031e+09  2.126270e+09
# Amount  5.580682e+10  6.736043e+10  5.898050e+10  6.023541e+10  6.430825e+10
# MA10    3.557355e+03  3.562379e+03  3.557113e+03  3.549488e+03  3.538681e+03
# SMA10   3.570779e+03  3.555639e+03  3.532292e+03  3.512159e+03  3.498193e+03
# EMA10   3.558211e+03  3.543457e+03  3.528548e+03  3.517753e+03  3.502069e+03
# WMA10   3.572178e+03  3.564315e+03  3.548804e+03  3.531412e+03  3.516809e+03
# RSI10   5.982889e+01  7.311416e+01  4.083359e+01  5.749545e+01  1.636549e+01
# VWAP10  2.481857e+03  2.482110e+03  2.482321e+03  2.482515e+03  2.482719e+03
#
# Date         4/16/21       4/19/21       4/20/21       4/21/21       4/22/21  \
# Open    3.445094e+03  3.449049e+03  3.496807e+03  3.493793e+03  3.521977e+03
# High    3.456723e+03  3.515881e+03  3.532791e+03  3.524541e+03  3.524707e+03
# Low     3.411097e+03  3.426821e+03  3.491893e+03  3.488490e+03  3.477059e+03
# Close   3.448104e+03  3.513395e+03  3.510124e+03  3.516098e+03  3.487427e+03
# Volume  1.868806e+09  2.719346e+09  2.117662e+09  2.075010e+09  2.267914e+09
# Amount  5.486265e+10  7.759157e+10  6.663395e+10  5.996686e+10  5.812070e+10
# MA10    3.527893e+03  3.514438e+03  3.504102e+03  3.495643e+03  3.491406e+03
# SMA10   3.479406e+03  3.470979e+03  3.483081e+03  3.490170e+03  3.498360e+03
# EMA10   3.492257e+03  3.496101e+03  3.498650e+03  3.501823e+03  3.499205e+03
# WMA10   3.497321e+03  3.482814e+03  3.482624e+03  3.483719e+03  3.487438e+03
# RSI10   5.758065e+01  5.536563e+01  3.225290e+01  2.679750e+01  6.253976e+01
# VWAP10  2.482900e+03  2.483176e+03  2.483396e+03  2.483611e+03  2.483844e+03
#
# Date    ...       5/12/21       5/13/21       5/14/21       5/17/21  \
# Open    ...  3.423420e+03  3.418581e+03  3.426425e+03  3.502740e+03
# High    ...  3.456069e+03  3.435447e+03  3.504648e+03  3.556493e+03
# Low     ...  3.421657e+03  3.395807e+03  3.406714e+03  3.502208e+03
# Close   ...  3.447862e+03  3.413889e+03  3.503037e+03  3.539912e+03
# Volume  ...  2.368968e+09  2.188267e+09  3.452725e+09  3.016509e+09
# Amount  ...  5.956658e+10  6.067001e+10  9.532370e+10  9.243118e+10
# MA10    ...  3.464337e+03  3.456721e+03  3.451344e+03  3.454017e+03
# SMA10   ...  3.440493e+03  3.441112e+03  3.433189e+03  3.454051e+03
# EMA10   ...  3.453489e+03  3.446289e+03  3.456607e+03  3.471753e+03
# WMA10   ...  3.448921e+03  3.445925e+03  3.438137e+03  3.447536e+03
# RSI10   ...  6.474998e+01  1.924008e+01  4.689175e+01  5.723790e+01
# VWAP10  ...  2.486723e+03  2.486928e+03  2.487270e+03  2.487588e+03
#
# Date         5/18/21       5/19/21       5/20/21       5/21/21       5/24/21  \
# Open    3.543110e+03  3.531788e+03  3.514428e+03  3.532872e+03  3.482993e+03
# High    3.550076e+03  3.531788e+03  3.530491e+03  3.544266e+03  3.499445e+03
# Low     3.520666e+03  3.501383e+03  3.496520e+03  3.475263e+03  3.457292e+03
# Close   3.537696e+03  3.511467e+03  3.522451e+03  3.481862e+03  3.497747e+03
# Volume  2.378259e+09  2.380663e+09  2.382720e+09  2.064464e+09  2.298654e+09
# Amount  5.721306e+10  6.055228e+10  6.320845e+10  6.117673e+10  6.453227e+10
# MA10    3.460705e+03  3.462753e+03  3.464781e+03  3.472032e+03  3.479588e+03
# SMA10   3.481057e+03  3.497314e+03  3.500395e+03  3.505779e+03  3.498425e+03
# EMA10   3.483743e+03  3.488784e+03  3.494905e+03  3.492534e+03  3.493481e+03
# WMA10   3.463154e+03  3.477152e+03  3.486009e+03  3.496495e+03  3.498282e+03
# RSI10   7.896041e+01  4.417165e+01  3.424691e+01  3.554701e+01  5.042196e+01
# VWAP10  2.487839e+03  2.488085e+03  2.488332e+03  2.488542e+03  2.488773e+03
#
# Date         5/25/21
# Open    3.505814e+03
# High    3.645075e+03
# Low     3.505626e+03
# Close   3.641292e+03
# Volume  4.418286e+09
# Amount  1.257360e+11
# MA10    3.489364e+03
# SMA10   3.499288e+03
# EMA10   3.520356e+03
# WMA10   3.501584e+03
# RSI10   7.691983e+01
# VWAP10  2.489265e+03
#
# [12 rows x 30 columns]

# %%
targets[0]
# Out:
# -0.01923725052326738

# %%
targets[-1]
# Out:
# 0.002639612678116096

# %%
train_size = int(len(samples) * 0.8)

train_data = np.array(samples[:train_size], dtype='float32')
test_data = np.array(samples[train_size:], dtype='float32')
train_targets = np.array(targets[:train_size], dtype='float32')
test_targets = np.array(targets[train_size:], dtype='float32')

# %% [markdown]
# ## Feature Extraction Functions

# %%
def ts_corr(X, Y, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        Ysub = Y[i-d+1:i+1]
        corr = np.corrcoef(Xsub, Ysub)[0,1]
        res.append(0 if np.isnan(corr) else corr)
        
        i -= s

    return np.array(res, dtype='float32')

# %%
def ts_cov(X, Y, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        Ysub = Y[i-d+1:i+1]
        cov = np.cov(Xsub, Ysub)[0,1]
        res.append(cov)
        
        i -= s
        
    return np.array(res, dtype='float32')

# %%
def ts_stdev(X, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        stdev = np.std(Xsub)
        res.append(stdev)
        
        i -= s
        
    return np.array(res, dtype='float32')

# %%
def ts_zscore(X, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        Xstd = np.std(Xsub)
        zscore = np.mean(Xsub) / (np.std(X) if Xstd == 0 else Xstd)
        res.append(zscore)
        
        i -= s
        
    return np.array(res, dtype='float32')

# %%
def ts_return(X, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        ret = (Xsub[-1] - Xsub[0]) / Xsub[0]
        res.append(ret)
        
        i -= s
        
    return np.array(res, dtype='float32')

# %%
def ts_decaylinear(X, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        Wsub = np.array([i for i in range(1, d+1)])
        weighted_sum = np.sum(Xsub * Wsub / np.sum(Wsub))
        res.append(weighted_sum)
        
        i -= s
        
    return np.array(res, dtype='float32')

# %%
a = np.array([1, 2, 3, 4, 5])
b = np.array([6, 7, 8, 9, 10])

# %%
ts_corr(a, b, d=3, s=3)
# Out:
# array([1.], dtype=float32)

# %%
ts_cov(a, b, d=3, s=3)
# Out:
# array([1.], dtype=float32)

# %%
ts_stdev(a, d=3, s=3)
# Out:
# array([0.8164966], dtype=float32)

# %%
ts_zscore(a, d=3, s=3)
# Out:
# array([4.8989797], dtype=float32)

# %%
ts_return(a, d=3, s=3)
# Out:
# array([0.6666667], dtype=float32)

# %%
ts_decaylinear(a, d=3, s=3)
# Out:
# array([4.3333335], dtype=float32)

# %% [markdown]
# ## Pooling Functions

# %%
def ts_min(X, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        vmin = tf.math.reduce_min(Xsub)
        res.append(vmin)
        i -= s
    
    res.reverse()
    
    return tf.convert_to_tensor(res)

# %%
def ts_max(X, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        vmax = tf.math.reduce_max(Xsub)
        res.append(vmax)
        i -= s
        
    res.reverse()
    
    return tf.convert_to_tensor(res)

# %%
def ts_mean(X, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        vmean = tf.math.reduce_mean(Xsub)
        res.append(vmean)
        i -= s
        
    res.reverse()
    
    return tf.convert_to_tensor(res)

# %% [markdown]
# ## Function to Generate Synthetic Features

# %%
def generate_syn_feats(feats, fn_names):
    syn_feats = []
    
    for fn in fn_names:
        if fn in ['ts_corr', 'ts_cov']:
            for r1, r2 in combinations(range(len(feats)), 2):
                f1 = feats[r1]
                f2 = feats[r2]
                syn_feats.append(f"N({fn}({f1},{f2}))")
        else:
            for feat in feats:
                syn_feats.append(f"N({fn}({feat}))")
    
    return syn_feats

# %%
syn_feats = generate_syn_feats(
    features,
    ["ts_corr", "ts_cov", "ts_stdev", "ts_zscore", "ts_return", "ts_decaylinear"]
)

# %%
features
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Amount', 'MA10', 'SMA10',
#        'EMA10', 'WMA10', 'RSI10', 'VWAP10'],
#       dtype='object')

# %%
syn_feats
# Out:
# ['N(ts_corr(Open,High))',
#  'N(ts_corr(Open,Low))',
#  'N(ts_corr(Open,Close))',
#  'N(ts_corr(Open,Volume))',
#  'N(ts_corr(Open,Amount))',
#  'N(ts_corr(Open,MA10))',
#  'N(ts_corr(Open,SMA10))',
#  'N(ts_corr(Open,EMA10))',
#  'N(ts_corr(Open,WMA10))',
#  'N(ts_corr(Open,RSI10))',
#  'N(ts_corr(Open,VWAP10))',
#  'N(ts_corr(High,Low))',
#  'N(ts_corr(High,Close))',
#  'N(ts_corr(High,Volume))',
#  'N(ts_corr(High,Amount))',
#  'N(ts_corr(High,MA10))',
#  'N(ts_corr(High,SMA10))',
#  'N(ts_corr(High,EMA10))',
#  'N(ts_corr(High,WMA10))',
#  'N(ts_corr(High,RSI10))',
#  'N(ts_corr(High,VWAP10))',
#  'N(ts_corr(Low,Close))',
#  'N(ts_corr(Low,Volume))',
#  'N(ts_corr(Low,Amount))',
#  'N(ts_corr(Low,MA10))',
#  'N(ts_corr(Low,SMA10))',
#  'N(ts_corr(Low,EMA10))',
#  'N(ts_corr(Low,WMA10))',
#  'N(ts_corr(Low,RSI10))',
#  'N(ts_corr(Low,VWAP10))',
#  'N(ts_corr(Close,Volume))',
#  'N(ts_corr(Close,Amount))',
#  'N(ts_corr(Close,MA10))',
#  'N(ts_corr(Close,SMA10))',
#  'N(ts_corr(Close,EMA10))',
#  'N(ts_corr(Close,WMA10))',
#  'N(ts_corr(Close,RSI10))',
#  'N(ts_corr(Close,VWAP10))',
#  'N(ts_corr(Volume,Amount))',
#  'N(ts_corr(Volume,MA10))',
#  'N(ts_corr(Volume,SMA10))',
#  'N(ts_corr(Volume,EMA10))',
#  'N(ts_corr(Volume,WMA10))',
#  'N(ts_corr(Volume,RSI10))',
#  'N(ts_corr(Volume,VWAP10))',
#  'N(ts_corr(Amount,MA10))',
#  'N(ts_corr(Amount,SMA10))',
#  'N(ts_corr(Amount,EMA10))',
#  'N(ts_corr(Amount,WMA10))',
#  'N(ts_corr(Amount,RSI10))',
#  'N(ts_corr(Amount,VWAP10))',
#  'N(ts_corr(MA10,SMA10))',
#  'N(ts_corr(MA10,EMA10))',
#  'N(ts_corr(MA10,WMA10))',
#  'N(ts_corr(MA10,RSI10))',
#  'N(ts_corr(MA10,VWAP10))',
#  'N(ts_corr(SMA10,EMA10))',
#  'N(ts_corr(SMA10,WMA10))',
#  'N(ts_corr(SMA10,RSI10))',
#  'N(ts_corr(SMA10,VWAP10))',
#  'N(ts_corr(EMA10,WMA10))',
#  'N(ts_corr(EMA10,RSI10))',
#  'N(ts_corr(EMA10,VWAP10))',
#  'N(ts_corr(WMA10,RSI10))',
#  'N(ts_corr(WMA10,VWAP10))',
#  'N(ts_corr(RSI10,VWAP10))',
#  'N(ts_cov(Open,High))',
#  'N(ts_cov(Open,Low))',
#  'N(ts_cov(Open,Close))',
#  'N(ts_cov(Open,Volume))',
#  'N(ts_cov(Open,Amount))',
#  'N(ts_cov(Open,MA10))',
#  'N(ts_cov(Open,SMA10))',
#  'N(ts_cov(Open,EMA10))',
#  'N(ts_cov(Open,WMA10))',
#  'N(ts_cov(Open,RSI10))',
#  'N(ts_cov(Open,VWAP10))',
#  'N(ts_cov(High,Low))',
#  'N(ts_cov(High,Close))',
#  'N(ts_cov(High,Volume))',
#  'N(ts_cov(High,Amount))',
#  'N(ts_cov(High,MA10))',
#  'N(ts_cov(High,SMA10))',
#  'N(ts_cov(High,EMA10))',
#  'N(ts_cov(High,WMA10))',
#  'N(ts_cov(High,RSI10))',
#  'N(ts_cov(High,VWAP10))',
#  'N(ts_cov(Low,Close))',
#  'N(ts_cov(Low,Volume))',
#  'N(ts_cov(Low,Amount))',
#  'N(ts_cov(Low,MA10))',
#  'N(ts_cov(Low,SMA10))',
#  'N(ts_cov(Low,EMA10))',
#  'N(ts_cov(Low,WMA10))',
#  'N(ts_cov(Low,RSI10))',
#  'N(ts_cov(Low,VWAP10))',
#  'N(ts_cov(Close,Volume))',
#  'N(ts_cov(Close,Amount))',
#  'N(ts_cov(Close,MA10))',
#  'N(ts_cov(Close,SMA10))',
#  'N(ts_cov(Close,EMA10))',
#  'N(ts_cov(Close,WMA10))',
#  'N(ts_cov(Close,RSI10))',
#  'N(ts_cov(Close,VWAP10))',
#  'N(ts_cov(Volume,Amount))',
#  'N(ts_cov(Volume,MA10))',
#  'N(ts_cov(Volume,SMA10))',
#  'N(ts_cov(Volume,EMA10))',
#  'N(ts_cov(Volume,WMA10))',
#  'N(ts_cov(Volume,RSI10))',
#  'N(ts_cov(Volume,VWAP10))',
#  'N(ts_cov(Amount,MA10))',
#  'N(ts_cov(Amount,SMA10))',
#  'N(ts_cov(Amount,EMA10))',
#  'N(ts_cov(Amount,WMA10))',
#  'N(ts_cov(Amount,RSI10))',
#  'N(ts_cov(Amount,VWAP10))',
#  'N(ts_cov(MA10,SMA10))',
#  'N(ts_cov(MA10,EMA10))',
#  'N(ts_cov(MA10,WMA10))',
#  'N(ts_cov(MA10,RSI10))',
#  'N(ts_cov(MA10,VWAP10))',
#  'N(ts_cov(SMA10,EMA10))',
#  'N(ts_cov(SMA10,WMA10))',
#  'N(ts_cov(SMA10,RSI10))',
#  'N(ts_cov(SMA10,VWAP10))',
#  'N(ts_cov(EMA10,WMA10))',
#  'N(ts_cov(EMA10,RSI10))',
#  'N(ts_cov(EMA10,VWAP10))',
#  'N(ts_cov(WMA10,RSI10))',
#  'N(ts_cov(WMA10,VWAP10))',
#  'N(ts_cov(RSI10,VWAP10))',
#  'N(ts_stdev(Open))',
#  'N(ts_stdev(High))',
#  'N(ts_stdev(Low))',
#  'N(ts_stdev(Close))',
#  'N(ts_stdev(Volume))',
#  'N(ts_stdev(Amount))',
#  'N(ts_stdev(MA10))',
#  'N(ts_stdev(SMA10))',
#  'N(ts_stdev(EMA10))',
#  'N(ts_stdev(WMA10))',
#  'N(ts_stdev(RSI10))',
#  'N(ts_stdev(VWAP10))',
#  'N(ts_zscore(Open))',
#  'N(ts_zscore(High))',
#  'N(ts_zscore(Low))',
#  'N(ts_zscore(Close))',
#  'N(ts_zscore(Volume))',
#  'N(ts_zscore(Amount))',
#  'N(ts_zscore(MA10))',
#  'N(ts_zscore(SMA10))',
#  'N(ts_zscore(EMA10))',
#  'N(ts_zscore(WMA10))',
#  'N(ts_zscore(RSI10))',
#  'N(ts_zscore(VWAP10))',
#  'N(ts_return(Open))',
#  'N(ts_return(High))',
#  'N(ts_return(Low))',
#  'N(ts_return(Close))',
#  'N(ts_return(Volume))',
#  'N(ts_return(Amount))',
#  'N(ts_return(MA10))',
#  'N(ts_return(SMA10))',
#  'N(ts_return(EMA10))',
#  'N(ts_return(WMA10))',
#  'N(ts_return(RSI10))',
#  'N(ts_return(VWAP10))',
#  'N(ts_decaylinear(Open))',
#  'N(ts_decaylinear(High))',
#  'N(ts_decaylinear(Low))',
#  'N(ts_decaylinear(Close))',
#  'N(ts_decaylinear(Volume))',
#  'N(ts_decaylinear(Amount))',
#  'N(ts_decaylinear(MA10))',
#  'N(ts_decaylinear(SMA10))',
#  'N(ts_decaylinear(EMA10))',
#  'N(ts_decaylinear(WMA10))',
#  'N(ts_decaylinear(RSI10))',
#  'N(ts_decaylinear(VWAP10))']

# %%
len(syn_feats)
# Out:
# 180

# %% [markdown]
# ## Function to Generate Synthetic Samples

# %%
def generate_syn_samples(train_data, test_data, width=2, strides=1):
    feomap = { 'train': [], 'test': [] }
    fefns = (ts_corr, ts_cov, ts_stdev, ts_zscore, ts_return, ts_decaylinear)
    nfeats = train_data[0].shape[0]
    
    for sample in train_data:
        feoutput = []
        
        for fefn in fefns:
            if fefn in [ts_corr, ts_cov]:
                for r1, r2 in combinations(range(nfeats), 2):
                    res = fefn(sample[r1], sample[r2], d=width, s=strides)
                    feoutput.append(res)
            else:
                for row in sample:
                    res = fefn(row, d=width, s=strides)
                    feoutput.append(res)
                    
        feomap['train'].append(feoutput)
        
    for sample in test_data:
        feoutput = []
        
        for fefn in fefns:
            if fefn in [ts_corr, ts_cov]:
                for r1, r2 in combinations(range(nfeats), 2):
                    res = fefn(sample[r1], sample[r2], d=width, s=strides)
                    feoutput.append(res)
            else:
                for row in sample:
                    res = fefn(row, d=width, s=strides)
                    feoutput.append(res)
                    
        feomap['test'].append(feoutput)
    
    feomap['train'] = np.array(feomap['train'], dtype='float32')
    feomap['test'] = np.array(feomap['test'], dtype='float32')
    
    # Normalize
    nrows, ncols = feomap['train'][0].shape
    
    for i in range(nrows):
        for j in range(ncols):
            arr = []
            
            for sample in feomap['train']:
                arr.append(sample[i,j])
                
            arr_mean = np.mean(arr)
            arr_stdev = np.std(arr)
            
            for sample in feomap['train']:
                sample[i,j] = (sample[i,j] - arr_mean) / arr_stdev
                
            for sample in feomap['test']:
                sample[i,j] = (sample[i,j] - arr_mean) / arr_stdev

    return feomap

# %%
syn_samples_dict = generate_syn_samples(train_data, test_data, width=3, strides=3)
# Out:
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# overflow encountered in multiply
# overflow encountered in reduce

# %%
syn_samples_dict['train'].shape
# Out:
# (1091, 180, 10)

# %%
syn_samples_dict['test'].shape
# Out:
# (273, 180, 10)

# %%
syn_train_data = syn_samples_dict['train']
syn_test_data = syn_samples_dict['test']

# %%
syn_train_data.shape
# Out:
# (1091, 180, 10)

# %%
syn_train_targets = train_targets
syn_test_targets = test_targets

# %%
syn_train_targets.shape
# Out:
# (1091,)

# %%
syn_test_targets.shape
# Out:
# (273,)

# %%
syn_train_data[0].shape
# Out:
# (180, 10)

# %%
model = models.Sequential()

model.add(layers.Input(shape=syn_train_data.shape[1:]))

model.add(layers.Flatten())
model.add(layers.Dense(30, activation='relu',
                       kernel_initializer=keras.initializers.TruncatedNormal(mean=0., stddev=1.)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1))
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

model.fit(syn_train_data, syn_train_targets, epochs=20, batch_size=32, verbose=0)
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.

# %%
model.evaluate(syn_test_data, syn_test_targets)
# Out:
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
# [0.7469655270978208, 0.6691787]

# %%
shap_dexp = shap.DeepExplainer(model, syn_train_data)
# Out:
# keras is no longer supported, please use tf.keras instead.
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode. See PR #1483 for discussion.

# %%
# 1 x number of samples x number of features x number of days

# sample1 + sample2 + ... + 

shap_values = shap_dexp.shap_values(syn_test_data)

shap_values = shap_values[0]
shap_values = np.hstack(shap_values)
shap_values = np.transpose(shap_values)

# %%
shap_values.shape
# Out:
# (2730, 180)

# %%
shap.summary_plot(shap_values, features=syn_test_data, feature_names=syn_feats, plot_type='bar')

# %%
X_test = np.hstack(syn_test_data)
X_test = np.transpose(X_test)
X_test_df = pd.DataFrame(X_test, columns=syn_feats)

# %%
X_test_df
# Out:
#       N(ts_corr(Open,High))  N(ts_corr(Open,Low))  N(ts_corr(Open,Close))  \
# 0                  0.693675              0.647036               -1.884798
# 1                 -2.646179              0.564157               -1.492221
# 2                  0.091488             -0.336560               -0.521155
# 3                  0.166964              0.701626                0.639869
# 4                 -0.032335              0.465946                0.457416
# ...                     ...                   ...                     ...
# 2725               0.695254              0.672831                1.062327
# 2726              -0.136170             -3.066331               -1.880701
# 2727               0.609612              0.701197               -0.457687
# 2728               0.563635              0.176112                0.563044
# 2729               0.785451              0.700350                1.207670
#
#       N(ts_corr(Open,Volume))  N(ts_corr(Open,Amount))  N(ts_corr(Open,MA10))  \
# 0                   -0.969355                -0.831747               0.680790
# 1                   -1.484978                -1.527307              -1.572614
# 2                   -0.110599                -0.019115               0.526242
# 3                   -0.306284                -0.416776               1.054326
# 4                   -1.408418                -1.138381               0.675706
# ...                       ...                      ...                    ...
# 2725                 1.008133                 0.264627               0.009084
# 2726                 1.246930                 0.621949               0.107441
# 2727                -1.480517                -1.392742              -1.432294
# 2728                 0.286738                 0.617334               1.066875
# 2729                -0.781794                -0.822194              -0.544884
#
#       N(ts_corr(Open,SMA10))  N(ts_corr(Open,EMA10))  N(ts_corr(Open,WMA10))  \
# 0                   0.513462                0.406397                0.599636
# 1                  -2.232865               -2.056207               -1.847217
# 2                   0.807731               -0.030973                0.541573
# 3                   0.788283                0.769738                0.935064
# 4                   0.278046                0.295677                0.423727
# ...                      ...                     ...                     ...
# 2725               -1.664068                0.814506               -1.377272
# 2726                0.821084               -2.040213                0.702588
# 2727                0.663014                0.576824               -0.041316
# 2728                0.812042                0.881631                0.948411
# 2729                0.698883                0.823141                0.830030
#
#       N(ts_corr(Open,RSI10))  ...  N(ts_decaylinear(Low))  \
# 0                   0.632711  ...                1.432494
# 1                  -1.080792  ...                1.087089
# 2                   0.632493  ...                1.058807
# 3                   0.997909  ...                1.047931
# 4                   1.101299  ...                0.892222
# ...                      ...  ...                     ...
# 2725               -1.709529  ...                3.168802
# 2726                0.402505  ...                3.203536
# 2727               -1.707640  ...                3.225992
# 2728               -0.252877  ...                3.068529
# 2729                0.248982  ...                3.189727
#
#       N(ts_decaylinear(Close))  N(ts_decaylinear(Volume))  \
# 0                     1.452896                   1.241965
# 1                     1.114225                   0.024095
# 2                     1.043571                   0.003675
# 3                     1.045780                  -0.136589
# 4                     0.911096                  -0.317803
# ...                        ...                        ...
# 2725                  3.164941                  -0.260857
# 2726                  3.154361                  -0.338912
# 2727                  3.208968                  -0.386769
# 2728                  3.056333                  -0.442368
# 2729                  3.121826                  -0.383659
#
#       N(ts_decaylinear(Amount))  N(ts_decaylinear(MA10))  \
# 0                      1.244918                 1.116450
# 1                      0.110676                 1.000470
# 2                      0.103787                 0.914791
# 3                     -0.061576                 0.820643
# 4                     -0.183757                 0.739603
# ...                         ...                      ...
# 2725                   0.710071                 3.154654
# 2726                   0.590361                 3.156379
# 2727                   0.455390                 3.195062
# 2728                   0.337534                 3.271343
# 2729                   0.377699                 3.324789
#
#       N(ts_decaylinear(SMA10))  N(ts_decaylinear(EMA10))  \
# 0                     1.230790                  1.197200
# 1                     1.041031                  1.015524
# 2                     0.983622                  0.949259
# 3                     0.907444                  0.883135
# 4                     0.786784                  0.774580
# ...                        ...                       ...
# 2725                  3.151915                  3.181613
# 2726                  3.183751                  3.198551
# 2727                  3.153120                  3.199085
# 2728                  3.167625                  3.198728
# 2729                  3.294094                  3.286668
#
#       N(ts_decaylinear(WMA10))  N(ts_decaylinear(RSI10))  \
# 0                     1.173790                  1.689436
# 1                     1.032232                  1.217878
# 2                     0.965451                  1.137804
# 3                     0.873418                  1.556843
# 4                     0.765588                  1.497875
# ...                        ...                       ...
# 2725                  3.162939                 -0.648298
# 2726                  3.166964                 -0.871499
# 2727                  3.150540                 -0.862152
# 2728                  3.210397                 -0.310548
# 2729                  3.320602                  0.234240
#
#       N(ts_decaylinear(VWAP10))
# 0                      1.282737
# 1                      1.275334
# 2                      1.272664
# 3                      1.270074
# 4                      1.267633
# ...                         ...
# 2725                   2.135840
# 2726                   2.129335
# 2727                   2.122352
# 2728                   2.114693
# 2729                   2.106865
#
# [2730 rows x 180 columns]

# %%
shap.summary_plot(shap_values, X_test, feature_names=syn_feats)

# %%
shap_values.shape
# Out:
# (2730, 180)

# %% [markdown]
# ## Define Custom Pooling Layers

# %%
class TSPoolLayer(layers.Layer):
    def __init__(self, pool_func, width, strides, name=None):
        super(TSPoolLayer, self).__init__()
        self.pool_func = pool_func
        self.width = width
        self.strides = strides
        self._name = name
        
    def build(self, input_shape):
        super(TSPoolLayer, self).build(input_shape)
        
    def call(self, x):
        n_feats = x.shape[1]
        result = [self.pool_func(x[i], self.width, self.strides) for i in range(n_feats)]
        return tf.convert_to_tensor(result, dtype='float32')

# %% [markdown]
# ## Define MinPooling1D Layer

# %%
class MinPooling1D(layers.MaxPooling1D):
    def __init__(self, pool_size=2, strides=None, padding='valid', data_format='channels_last', **kwargs):
        super(MinPooling1D, self).__init__(
            pool_size=pool_size,
            strides=strides,
            padding=padding,
            data_format=data_format,
            **kwargs)
        
    def pooling_function(inputs, pool_size, strides, padding, data_format):
        return -K.pool1d(-inputs, pool_size, strides, padding, data_format, pool_mode='max')

# %% [markdown]
# ## Define AlphaNet Model

# %%
K.clear_session()

model_input = layers.Input(shape=(syn_train_data.shape[-2],
                                 syn_train_data.shape[-1]), dtype='float32', name='input')
input_flattened = layers.Flatten(name='input_flat')(model_input)

#mean3_pooling_layer = TSPoolLayer(ts_mean, 3, 1, name='mean3')(model_input)
mean3_pooling_layer = layers.AveragePooling1D(3, name='mean3')(model_input)
mean3_bn_layer = layers.BatchNormalization(axis=1, name='mean3_bn')(mean3_pooling_layer)
mean3_bn_flattened = layers.Flatten(name='mean3_bn_flat')(mean3_bn_layer)

#max3_pooling_layer = TSPoolLayer(ts_max, 3, 1, name='max3')(model_input)
max3_pooling_layer = layers.MaxPooling1D(3, name='max3')(model_input)
max3_bn_layer = layers.BatchNormalization(axis=1, name='max3_bn')(max3_pooling_layer)
max3_bn_flattened = layers.Flatten(name='max3_bn_flat')(max3_bn_layer)

# min3_pooling_layer = TSPoolLayer(ts_min, 3, 1, name='min3')(model_input)
min3_pooling_layer = MinPooling1D(3, name='min3')(model_input)
min3_bn_layer = layers.BatchNormalization(axis=1, name='min3_bn')(min3_pooling_layer)
min3_bn_flattened = layers.Flatten(name='min3_bn_flat')(min3_bn_layer)

concatenated = layers.concatenate([
    input_flattened, \
    mean3_bn_flattened, \
    max3_bn_flattened, \
    min3_bn_flattened], name='concat')

dense_layer = layers.Dense(30, activation='relu',
                       kernel_initializer=keras.initializers.TruncatedNormal(mean=0., stddev=1.), \
                           name='dense')(concatenated)

dropout_layer = layers.Dropout(0.5, name='dropout')(dense_layer)

model_output = layers.Dense(1, name='output')(dropout_layer)

model = models.Model(model_input, model_output)

model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

model.summary()
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/layers/normalization.py:534: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 180, 10)]    0
# __________________________________________________________________________________________________
# mean3 (AveragePooling1D)        (None, 60, 10)       0           input[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling1D)             (None, 60, 10)       0           input[0][0]
# __________________________________________________________________________________________________
# min3 (MinPooling1D)             (None, 60, 10)       0           input[0][0]
# __________________________________________________________________________________________________
# mean3_bn (BatchNormalization)   (None, 60, 10)       240         mean3[0][0]
# __________________________________________________________________________________________________
# max3_bn (BatchNormalization)    (None, 60, 10)       240         max3[0][0]
# __________________________________________________________________________________________________
# min3_bn (BatchNormalization)    (None, 60, 10)       240         min3[0][0]
# __________________________________________________________________________________________________
# input_flat (Flatten)            (None, 1800)         0           input[0][0]
# __________________________________________________________________________________________________
# mean3_bn_flat (Flatten)         (None, 600)          0           mean3_bn[0][0]
# __________________________________________________________________________________________________
# max3_bn_flat (Flatten)          (None, 600)          0           max3_bn[0][0]
# __________________________________________________________________________________________________
# min3_bn_flat (Flatten)          (None, 600)          0           min3_bn[0][0]
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, 3600)         0           input_flat[0][0]
#                                                                  mean3_bn_flat[0][0]
#                                                                  max3_bn_flat[0][0]
#                                                                  min3_bn_flat[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 30)           108030      concat[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 30)           0           dense[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            31          dropout[0][0]
# ==================================================================================================
# Total params: 108,781
# Trainable params: 108,421
# Non-trainable params: 360
# __________________________________________________________________________________________________

# %%
model.fit(syn_train_data, syn_train_targets, epochs=20, batch_size=32, verbose=0)

# %%
model.evaluate(syn_test_data, syn_test_targets)
# Out:
# `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
# [1.4791796098261962, 0.44044623]

# %%
shap_dexp = shap.DeepExplainer(model, syn_train_data)

shap_values = shap_dexp.shap_values(syn_test_data)

shap_values = shap_values[0]
shap_values = np.hstack(shap_values)
shap_values = np.transpose(shap_values)
# Out:
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode. See PR #1483 for discussion.

# %%
shap.summary_plot(shap_values, features=syn_test_data, feature_names=syn_feats, plot_type='bar')

# %%
shap.summary_plot(shap_values, X_test, feature_names=syn_feats)

# %%
shap_values.shape
# Out:
# (2730, 180)

# %%
X_test.shape
# Out:
# (2730, 180)

# %%
shap_values[:,68]
# Out:
# array([ 0.00270548,  0.00163464, -0.00084748, ..., -0.05485683,
#         0.00837325, -0.07426555])

# %%
for i in range(len(syn_feats)):
    if syn_feats[i] == 'N(ts_cov(Open,Close))':
        print(i)
        print(syn_feats[i])
# Out:
# 68
# N(ts_cov(Open,Close))

# %%
rows_to_remove = []

for j in range(shap_values.shape[1]):
    # For each column, find the rows that contain outliers
    col = shap_values[:,j]
    
    for i in range(len(col)):
        val = shap_values[i,j]
        
        if val < -0.2 or val > 0.2:
            rows_to_remove.append(i)
            
rows_to_remove
# Out:
# [1691,
#  2314,
#  2726,
#  1231,
#  1234,
#  1694,
#  2726,
#  2721,
#  2724,
#  2721,
#  41,
#  1238,
#  2725,
#  2721,
#  49,
#  1236,
#  2374,
#  2727,
#  2727,
#  2729,
#  182,
#  1692,
#  96,
#  91,
#  1468,
#  2721,
#  2721,
#  2723,
#  1756,
#  1692,
#  1755,
#  2721,
#  2726,
#  2728,
#  2729,
#  2721,
#  2723,
#  2723,
#  2726,
#  1236,
#  2721,
#  2723,
#  2722,
#  2723,
#  2726,
#  2726,
#  2723,
#  1232,
#  1462,
#  2720,
#  2724,
#  2728,
#  2722,
#  2312,
#  2620,
#  2724,
#  2729,
#  1234,
#  1696,
#  2725,
#  2726,
#  1237,
#  2720,
#  2721,
#  2727,
#  2726,
#  2727,
#  2720,
#  2721,
#  2721,
#  2727,
#  2729,
#  1237,
#  2721,
#  2724,
#  2721,
#  2721,
#  1234,
#  1753,
#  2720,
#  2725,
#  40,
#  70,
#  1753,
#  1690,
#  2725,
#  1232,
#  2721,
#  2722,
#  1238,
#  2720,
#  2720,
#  2720,
#  2720,
#  1234,
#  1753,
#  1142,
#  1231,
#  1238,
#  2721,
#  2725,
#  2722,
#  2722,
#  2728,
#  104,
#  1141,
#  1173,
#  1237,
#  1650,
#  1661,
#  1682,
#  1690,
#  1693,
#  1754,
#  1130,
#  1141,
#  1173,
#  1237,
#  1269,
#  1650,
#  1661,
#  1757,
#  1130,
#  1141,
#  1237,
#  1269,
#  1438,
#  1650,
#  1693,
#  1757,
#  1789,
#  1173,
#  1661,
#  1693,
#  1789,
#  1173,
#  1237,
#  1661,
#  1682,
#  1683,
#  1690,
#  1693,
#  1757,
#  1439,
#  1650,
#  1682,
#  1693,
#  1746,
#  1799,
#  2376,
#  107,
#  184,
#  1237,
#  1682,
#  1690,
#  1746,
#  1754,
#  1757,
#  107,
#  1141,
#  1173,
#  1237,
#  1269,
#  1650,
#  1661,
#  1682,
#  1757,
#  2722,
#  1141,
#  1237,
#  1438,
#  1650,
#  1682,
#  1757,
#  1130,
#  1173,
#  1237,
#  1753,
#  2312,
#  2727,
#  1682,
#  107,
#  1237,
#  1269,
#  1650,
#  1661,
#  1682,
#  1690,
#  1693,
#  1757,
#  2722,
#  75,
#  107,
#  1141,
#  1237,
#  1269,
#  1650,
#  1661,
#  1682,
#  1690,
#  1693,
#  1757,
#  2720,
#  2722,
#  107,
#  1237,
#  1650,
#  1661,
#  1682,
#  1757,
#  2720,
#  107,
#  1173,
#  1237,
#  1650,
#  1661,
#  1682,
#  1683,
#  1690,
#  1693,
#  1789,
#  2720,
#  1141,
#  1236,
#  1237,
#  1650,
#  1661,
#  1682,
#  1693,
#  1757,
#  1789,
#  2312,
#  2376,
#  43,
#  107,
#  1661,
#  1682,
#  1693,
#  1746,
#  1754,
#  1757,
#  43,
#  1141,
#  1173,
#  1237,
#  1269,
#  1650,
#  1661,
#  1682,
#  1693,
#  1757,
#  1789,
#  2720,
#  75,
#  95,
#  107,
#  1236,
#  1237,
#  1650,
#  1661,
#  1693,
#  1141,
#  1237,
#  1690,
#  2172,
#  2312,
#  2720,
#  2722,
#  2724,
#  2725,
#  1757,
#  1141,
#  1173,
#  1269,
#  1650,
#  1682,
#  1690,
#  1693,
#  75,
#  95,
#  1682,
#  1757,
#  43,
#  75,
#  95,
#  1141,
#  1650,
#  1682,
#  1693,
#  1757,
#  2720,
#  1438,
#  1650,
#  1682,
#  1752,
#  43,
#  75,
#  1650,
#  1757,
#  1799,
#  107,
#  1141,
#  1173,
#  1237,
#  1269,
#  1650,
#  1661,
#  1789,
#  1438,
#  1650,
#  1682,
#  1693,
#  1230,
#  1237,
#  2725,
#  1141,
#  1237,
#  1650,
#  1661,
#  1693,
#  2720,
#  1650,
#  1661,
#  1682,
#  1693,
#  1746,
#  2720,
#  2722,
#  1141,
#  1237,
#  1438,
#  1650,
#  1757,
#  1797,
#  2311,
#  2556,
#  1237,
#  1269,
#  1650,
#  1661,
#  1690,
#  1693,
#  1754,
#  1757,
#  1789,
#  2555,
#  43,
#  75,
#  1141,
#  1173,
#  1237,
#  1269,
#  1650,
#  1661,
#  1682,
#  1692,
#  1746,
#  1789,
#  2311,
#  2375,
#  1141,
#  1173,
#  1661,
#  1681,
#  1692,
#  1789,
#  90,
#  106,
#  1704,
#  2720,
#  2722,
#  2724,
#  1693,
#  1757,
#  95,
#  1236,
#  1693,
#  1756,
#  1757,
#  1690,
#  1692,
#  1757,
#  75,
#  95,
#  107,
#  1650,
#  1682,
#  1692,
#  1693,
#  1757,
#  1789,
#  107,
#  1682,
#  1692,
#  1693,
#  1756,
#  2172,
#  1236,
#  1650,
#  1660,
#  1682,
#  1692,
#  1693,
#  1757,
#  1788,
#  1692,
#  1693,
#  1757,
#  1788,
#  43,
#  75,
#  95,
#  107,
#  1650,
#  1661,
#  1683,
#  1692,
#  1693,
#  1756,
#  1757,
#  1789,
#  2720,
#  95,
#  1650,
#  1660,
#  1693,
#  1746,
#  1754,
#  1756,
#  1757,
#  1799,
#  1699,
#  2720,
#  2722,
#  2723,
#  2726,
#  1650,
#  1660,
#  1681,
#  1692,
#  1703,
#  1735,
#  1757,
#  1650,
#  1682,
#  1692,
#  1693,
#  1756,
#  1757,
#  1788,
#  2375,
#  1140,
#  1236,
#  1660,
#  1681,
#  1682,
#  1691,
#  1755,
#  1756,
#  1799,
#  2375,
#  2555,
#  182,
#  1233,
#  1699,
#  2312,
#  1650,
#  1660,
#  1692,
#  1693,
#  1746,
#  1757,
#  1799,
#  2376,
#  1236,
#  1650,
#  1660,
#  1661,
#  1681,
#  1692,
#  1703,
#  1745,
#  1756,
#  1788,
#  2555,
#  93,
#  99,
#  189,
#  2312,
#  2376,
#  1682,
#  1692,
#  1439,
#  1650,
#  1660,
#  1661,
#  1681,
#  1682,
#  1692,
#  1693,
#  1755,
#  1757,
#  1788,
#  1789,
#  1799,
#  106,
#  1237,
#  2376,
#  2720,
#  1650,
#  106,
#  182,
#  2312,
#  2729,
#  43,
#  120,
#  1141,
#  1237,
#  1690,
#  1693,
#  2312,
#  43,
#  75,
#  95,
#  104,
#  1141,
#  1650,
#  1683,
#  1690,
#  1693,
#  1789,
#  2720,
#  2722,
#  107,
#  1141,
#  1230,
#  1237,
#  1650,
#  1754,
#  43,
#  107,
#  1141,
#  1237,
#  1269,
#  1650,
#  1661,
#  1682,
#  1693,
#  2720,
#  2722,
#  1692,
#  1754,
#  1236,
#  1439,
#  1691,
#  1692,
#  1756,
#  2556,
#  107,
#  1236,
#  1650,
#  1692,
#  1693,
#  1756,
#  1799,
#  2376,
#  43,
#  106,
#  107,
#  1141,
#  1237,
#  1650,
#  1692,
#  1693,
#  2720,
#  107,
#  1140,
#  1439,
#  1650,
#  1660,
#  1661,
#  1681,
#  1692,
#  1693,
#  1755,
#  1756,
#  1757,
#  1788,
#  2375,
#  2555,
#  1233,
#  1467,
#  180,
#  2249,
#  108,
#  793,
#  1144,
#  1170,
#  1234,
#  2001,
#  1460,
#  1657,
#  1753,
#  2727,
#  1691,
#  1755,
#  2314,
#  2567,
#  2721,
#  349,
#  1232,
#  1235,
#  1267,
#  1468,
#  1695,
#  2725,
#  1658,
#  2310,
#  2374,
#  790,
#  2373,
#  2452,
#  2516,
#  2727,
#  1661,
#  1692,
#  1756,
#  1757,
#  43,
#  107,
#  1141,
#  1237,
#  1682,
#  1237,
#  1269,
#  1661,
#  1693,
#  1757,
#  2720,
#  1237,
#  1753,
#  2723,
#  1682,
#  2720,
#  2725,
#  2720,
#  1691,
#  1756,
#  1236,
#  1682,
#  1693,
#  1756,
#  1799,
#  2312,
#  107,
#  1237,
#  1661,
#  1682,
#  1756,
#  1757,
#  1692,
#  1233,
#  1681,
#  1690,
#  1691,
#  1754,
#  1758,
#  2372,
#  2453,
#  2723,
#  2726,
#  2729,
#  102,
#  181,
#  1238,
#  1239,
#  1691,
#  1692,
#  1699,
#  1753,
#  1754,
#  1755,
#  1757,
#  2311,
#  2559,
#  2720,
#  2722,
#  2723,
#  2725,
#  2728,
#  2729,
#  41,
#  91,
#  101,
#  108,
#  1143,
#  1230,
#  1233,
#  1234,
#  1238,
#  1430,
#  1461,
#  1465,
#  1655,
#  1660,
#  1662,
#  1692,
#  1698,
#  1750,
#  1751,
#  1753,
#  1756,
#  1758,
#  2312,
#  2313,
#  2317,
#  2451,
#  2551,
#  2557,
#  2622,
#  2720,
#  2723,
#  2726,
#  2727,
#  2729,
#  43,
#  93,
#  1236,
#  1462,
#  1463,
#  1691,
#  1692,
#  1753,
#  2174,
#  2310,
#  2312,
#  2314,
#  2315,
#  2370,
#  2374,
#  2376,
#  2554,
#  2574,
#  2624,
#  2721,
#  2722,
#  2724,
#  2726,
#  2728,
#  2729,
#  1693,
#  1755,
#  102,
#  1147,
#  1232,
#  1690,
#  1754,
#  1755,
#  2312,
#  2370,
#  2374,
#  2519,
#  2556,
#  2720,
#  2721,
#  2722,
#  2723,
#  2725,
#  2726,
#  2727,
#  1231,
#  1239,
#  1693,
#  1699,
#  1756,
#  1757,
#  1759,
#  2310,
#  2311,
#  2373,
#  2376,
#  2377,
#  2557,
#  2623,
#  2720,
#  2721,
#  2723,
#  2726,
#  2727,
#  1231,
#  1234,
#  1236,
#  1261,
#  1750,
#  1752,
#  2553,
#  2721,
#  2722,
#  2725,
#  2726,
#  2727,
#  2729,
#  1144,
#  1146,
#  1149,
#  1174,
#  1230,
#  1235,
#  1696,
#  1697,
#  2310,
#  2313,
#  2315,
#  2317,
#  2371,
#  2373,
#  2375,
#  2376,
#  2551,
#  2553,
#  2555,
#  2556,
#  2565,
#  2569,
#  2621,
#  2625,
#  2720,
#  2722,
#  2723,
#  2724,
#  2725,
#  2726,
#  2727,
#  2729,
#  1231,
#  1234,
#  1463,
#  1465,
#  2721,
#  2727]

# %%
rows_to_keep = []
for i in range(shap_values.shape[0]):
    if i not in rows_to_remove:
        rows_to_keep.append(i)

len(rows_to_keep)
# Out:
# 2578

# %%
shap_values_cln = shap_values[rows_to_keep]
X_test_cln = X_test[rows_to_keep]

# %%
shap.summary_plot(shap_values_cln, X_test_cln, feature_names=syn_feats)

# %%
K.clear_session()

model_input = layers.Input(shape=(syn_train_data.shape[-2],
                                 syn_train_data.shape[-1]), dtype='float32', name='input')

mean3_pooling_layer = layers.AveragePooling1D(3, name='mean3')(model_input)
mean3_bn_layer = layers.BatchNormalization(axis=1, name='mean3_bn')(mean3_pooling_layer)

max3_pooling_layer = layers.MaxPooling1D(3, name='max3')(model_input)
max3_bn_layer = layers.BatchNormalization(axis=1, name='max3_bn')(max3_pooling_layer)

min3_pooling_layer = MinPooling1D(3, name='min3')(model_input)
min3_bn_layer = layers.BatchNormalization(axis=1, name='min3_bn')(min3_pooling_layer)

input_gru = layers.GRU(32, name='input_gru')(model_input)
mean3_bn_gru = layers.GRU(32, name='mean3_bn_gru')(mean3_bn_layer)
max3_bn_gru = layers.GRU(32, name='max3_bn_gru')(max3_bn_layer)
min3_bn_gru = layers.GRU(32, name='min3_bn_gru')(min3_bn_layer)

concatenated = layers.concatenate([
    input_gru, \
    mean3_bn_gru, \
    max3_bn_gru, \
    min3_bn_gru], name='concat')

dropout_layer = layers.Dropout(0.5, name='dropout')(concatenated)

model_output = layers.Dense(1, name='output')(dropout_layer)

model = models.Model(model_input, model_output)

model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 180, 10)]    0
# __________________________________________________________________________________________________
# mean3 (AveragePooling1D)        (None, 60, 10)       0           input[0][0]
# __________________________________________________________________________________________________
# max3 (MaxPooling1D)             (None, 60, 10)       0           input[0][0]
# __________________________________________________________________________________________________
# min3 (MinPooling1D)             (None, 60, 10)       0           input[0][0]
# __________________________________________________________________________________________________
# mean3_bn (BatchNormalization)   (None, 60, 10)       240         mean3[0][0]
# __________________________________________________________________________________________________
# max3_bn (BatchNormalization)    (None, 60, 10)       240         max3[0][0]
# __________________________________________________________________________________________________
# min3_bn (BatchNormalization)    (None, 60, 10)       240         min3[0][0]
# __________________________________________________________________________________________________
# input_gru (GRU)                 (None, 32)           4224        input[0][0]
# __________________________________________________________________________________________________
# mean3_bn_gru (GRU)              (None, 32)           4224        mean3_bn[0][0]
# __________________________________________________________________________________________________
# max3_bn_gru (GRU)               (None, 32)           4224        max3_bn[0][0]
# __________________________________________________________________________________________________
# min3_bn_gru (GRU)               (None, 32)           4224        min3_bn[0][0]
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, 128)          0           input_gru[0][0]
#                                                                  mean3_bn_gru[0][0]
#                                                                  max3_bn_gru[0][0]
#                                                                  min3_bn_gru[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           concat[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            129         dropout[0][0]
# ==================================================================================================
# Total params: 17,745
# Trainable params: 17,385
# Non-trainable params: 360
# __________________________________________________________________________________________________

# %%
model.fit(syn_train_data, syn_train_targets, epochs=20, batch_size=32, verbose=0)

# %%
model.evaluate(syn_test_data, syn_test_targets)
# Out:
# [0.0009496679483493278, 0.02292111]

# %%
shap_dexp = shap.DeepExplainer(model, syn_train_data)

shap_values = shap_dexp.shap_values(syn_test_data)

shap_values = shap_values[0]
shap_values = np.hstack(shap_values)
shap_values = np.transpose(shap_values)

# %%
shap.summary_plot(shap_values, features=syn_test_data, feature_names=syn_feats, plot_type='bar')

# %%
shap.summary_plot(shap_values, X_test, feature_names=syn_feats)
