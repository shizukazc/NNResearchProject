# %%
import datetime
import requests
from lxml import etree
import pandas as pd
import akshare as ak
import time
from itertools import combinations

# %%
date = ak.tool_trade_date_hist_sina()
date =date.loc[date['trade_date']>='2015-04-16']

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import shap

from tensorflow.keras import models, layers

# %%
df = pd.read_csv("SSE50_2010_2021.csv")

# %%
df = df[['amount','volume','low','trade_date','open','change','high','close']]

# %%
df['return'] = df['close'].pct_change()

# %%
df
# Out:
#             amount        volume        low  trade_date       open   change  \
# 0     3.646852e+10  2.732744e+09  2514.2370  2010-01-04  2565.1080 -39.1540
# 1     5.077912e+10  3.537744e+09  2487.0480  2010-01-05  2526.2910  29.3450
# 2     4.344433e+10  2.964615e+09  2513.3650  2010-01-06  2538.2850 -29.9770
# 3     4.461141e+10  3.204318e+09  2450.4020  2010-01-07  2516.0570 -50.2560
# 4     3.233506e+10  2.268341e+09  2432.0130  2010-01-08  2453.0610   2.4070
# ...            ...           ...        ...         ...        ...      ...
# 2767  9.658566e+10  3.455940e+09  3643.9848  2021-05-26  3656.3403  15.8980
# 2768  8.514700e+10  2.987912e+09  3628.9596  2021-05-27  3645.4823   7.7519
# 2769  8.046883e+10  2.868285e+09  3630.5739  2021-05-28  3663.8753  -5.6460
# 2770  7.791793e+10  2.632840e+09  3615.4225  2021-05-31  3652.8877  -9.0712
# 2771  8.285057e+10  2.816155e+09  3608.2042  2021-06-01  3641.9690   0.6789
#
#            high      close    return
# 0     2570.1520  2514.6460       NaN
# 1     2560.6670  2543.9910  0.011670
# 2     2549.5710  2514.0140 -0.011783
# 3     2527.4270  2463.7580 -0.019990
# 4     2470.0240  2466.1650  0.000977
# ...         ...        ...       ...
# 2767  3678.0671  3657.1898  0.004366
# 2768  3709.0023  3664.9417  0.002120
# 2769  3689.2479  3659.2957 -0.001541
# 2770  3652.8924  3650.2245 -0.002479
# 2771  3652.9485  3650.9034  0.000186
#
# [2772 rows x 9 columns]

# %%
def generate_ma(df,window_size = 10):
    new_df = df.copy()
    for i in range(new_df.shape[0]-window_size):
        price_list = new_df.iloc[i:i + window_size]['close']
        avg = np.average(price_list)
        new_df.loc[new_df.index == i + window_size,'{}_MA'.format(window_size)] = avg
    return new_df

# %%
def generate_ema(df,window_size = 10):
    new_df = df.copy()
    weights = np.arange(window_size) + 1
    for i in range(new_df.shape[0] - window_size):
        price_list = new_df.iloc[i:i + window_size]['close']
        ema = np.sum(weights*price_list)/np.sum(weights)
        new_df.loc[new_df.index == i + window_size,'{}_EMA'.format(window_size)] = ema
    return new_df

# %%
def generate_sma(df, coef, window_size = 10):
    new_df = df.copy()
    for i in range(new_df.shape[0] - window_size):
        price_list = new_df.iloc[i:i + window_size]['close']
        price_list = np.array(price_list)
        Y = price_list[0]
        for j in range(1,window_size):
            Y_new = (price_list[j]*coef + (window_size - coef)* Y)/window_size
            Y = Y_new
        sma = Y
        new_df.loc[new_df.index == i + window_size,'{}_SMA'.format(window_size)] = sma
    return new_df

# %%
def generate_data(df,window_size,features,rolling_step,return_lagging):
    data_size = df.shape[0]
    x_index = 0
    label_index = window_size + return_lagging - 1
    X = []
    y = []
    while label_index < data_size:
        x_df = df.iloc[x_index:x_index + window_size][features].T
        x_data = x_df.values
        y_data = df.iloc[label_index]['IndexLogDailyReturn']
        X.append(x_data)
        y.append(y_data)
        label_index += rolling_step
        x_index += rolling_step
    X = np.array(X)
    y = np.array(y)
    return X,y

# %%
def generate_rsi(df, window_size = 14):
    new_df = df.copy()
    for i in range(new_df.shape[0] - window_size):
        price_list = new_df.iloc[i:i + window_size]['close']
        diff = np.diff(np.array(price_list))
        abs_diff = np.abs(diff)
        pos_diff = diff
        pos_diff[pos_diff < 0] = 0
        Y_abs = abs_diff[0]
        Y_pos = pos_diff[0]
        for j in range(1,window_size-1):
            Y_new_abs = (abs_diff[j] * 1 + (window_size - 1)* Y_abs)/window_size
            Y_abs = Y_new_abs
            Y_new_pos = (pos_diff[j] * 1 + (window_size - 1)* Y_pos)/window_size
            Y_pos = Y_new_pos
        rsi = Y_pos/Y_abs * 100
        new_df.loc[new_df.index == i + window_size,'{}_RSI'.format(window_size)] = rsi
    return new_df

# %%
def generate_vwap(df):
    _open = df['open']
    _high = df['high']
    _low = df['low']
    _volume = df['volume']
    cum_volume = np.cumsum(_volume)
    _average = (_open + _high + _low)/3
    nominator = _average * _volume
    cum_nominator = np.cumsum(nominator)
    VWAP = cum_nominator / cum_volume
    VWAP = pd.Series(VWAP)
    new_df = pd.concat((df, VWAP.rename('VWAP')),axis = 1)
    return new_df

# %%
df.iloc[10:100]
# Out:
#           amount        volume       low  trade_date      open  change  \
# 10  4.186666e+10  3.093634e+09  2398.778  2010-01-18  2414.893  -6.619
# 11  3.754464e+10  2.782908e+09  2424.161  2010-01-19  2424.469  11.525
# 12  4.572057e+10  3.474848e+09  2356.161  2010-01-20  2436.647 -73.228
# 13  3.780439e+10  2.919615e+09  2346.148  2010-01-21  2362.597  18.268
# 14  4.904208e+10  4.063927e+09  2317.481  2010-01-22  2344.973   2.302
# ..           ...           ...       ...         ...       ...     ...
# 95  1.434550e+10  1.385330e+09  1948.403  2010-05-26  1962.926  -0.515
# 96  2.013428e+10  1.899476e+09  1927.671  2010-05-27  1952.966  25.009
# 97  1.943545e+10  1.859205e+09  1964.408  2010-05-28  2001.195  -9.330
# 98  1.744814e+10  1.757968e+09  1924.893  2010-05-31  1961.699 -47.513
# 99  1.783377e+10  1.832762e+09  1895.906  2010-06-01  1916.623 -14.677
#
#         high     close    return
# 10  2421.890  2421.188 -0.002726
# 11  2450.281  2432.713  0.004760
# 12  2439.468  2359.485 -0.030101
# 13  2391.508  2377.753  0.007742
# 14  2398.989  2380.055  0.000968
# ..       ...       ...       ...
# 95  1974.787  1957.943 -0.000263
# 96  1987.882  1982.952  0.012773
# 97  2005.398  1973.622 -0.004705
# 98  1975.587  1926.109 -0.024074
# 99  1938.176  1911.432 -0.007620
#
# [90 rows x 9 columns]

# %%
df = generate_vwap(df)

# %%
df = generate_ma(df,10)

# %%
df = generate_ema(df,10)

# %%
df = generate_sma(df,3,10)

# %%
df = generate_rsi(df,10)

# %%
df = df.iloc[10:]
df.set_index('trade_date', inplace = True)
df = df.T

# %%
df.loc['amount'] = df.loc['amount']/1000000
df.loc['volume'] = df.loc['volume']/1000000

# %%
df.columns
# Out:
# Index(['2010-01-18', '2010-01-19', '2010-01-20', '2010-01-21', '2010-01-22',
#        '2010-01-25', '2010-01-26', '2010-01-27', '2010-01-28', '2010-01-29',
#        ...
#        '2021-05-19', '2021-05-20', '2021-05-21', '2021-05-24', '2021-05-25',
#        '2021-05-26', '2021-05-27', '2021-05-28', '2021-05-31', '2021-06-01'],
#       dtype='object', name='trade_date', length=2762)

# %%
# rtdays=5 means the target value would be the 5-day return
def generate_samples(data, rtdays=5, width=30, strides=1):
    dates = []
    samples = []
    targets = []
    
    i = data.shape[1] - 1 - rtdays
    
    while i - width + 1 >= 0:
        rt = (data.iloc[6,i+rtdays] - data.iloc[6,i]) / data.iloc[6,i]
        
        dates.append(data.columns[i])
        samples.append(data.iloc[:,i-width+1:i+1])
        targets.append(rt)
        
        i -= strides
    
    dates.reverse()
    samples.reverse()
    targets.reverse()
    
    return dates, samples, targets

# %%
dates, samples, targets = generate_samples(df, strides=2)

# %%
def ts_corr(X, Y, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        Ysub = Y[i-d+1:i+1]
        corr = np.corrcoef(Xsub, Ysub)
        corr[np.isnan(corr)] = 0
        corr = corr[0,1]
        
        res.append(corr)
        
        i -= s
    return np.array(res, dtype='float32')
def ts_cov(X, Y, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        Ysub = Y[i-d+1:i+1]
        cov = np.cov(Xsub, Ysub)[0,1]
        res.append(cov)
        
        i -= s   
    return np.array(res, dtype='float32')
def ts_stdev(X, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        stdev = np.std(Xsub)
        res.append(stdev)
        
        i -= s
    return np.array(res, dtype='float32')
def ts_zscore(X, d=2, s=1):  #Note, will will return inf if RSI maintain the same in the rolling window.
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        zscore = np.mean(Xsub) / np.std(Xsub)
        res.append(zscore)
        
        i -= s  
    return np.array(res, dtype='float32')
def ts_return(X, d=2, s=1):   #Note, it will return inf if RSI once hit 0
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        ret = (Xsub[-1] - Xsub[0]) / Xsub[0]
        res.append(ret)
        
        i -= s
    return np.array(res, dtype='float32')
def ts_decaylinear(X, d=2, s=1):
    res = []
    i = len(X) - 1
    
    while i - d + 1 >= 0:
        Xsub = X[i-d+1:i+1]
        Wsub = np.array([i for i in range(1, d+1)])
        weighted_sum = np.sum(Xsub * Wsub / np.sum(Wsub))
        res.append(weighted_sum)
        
        i -= s
    return np.array(res, dtype='float32')

# %%
def generate_syn_feats(feats, fn_names):
    syn_feats = []
    
    for fn in fn_names:
        if fn in ['ts_corr', 'ts_cov']:
            for r1, r2 in combinations(range(len(feats)), 2):
                f1 = feats[r1]
                f2 = feats[r2]
                syn_feats.append(f"N({fn}({f1},{f2}))")
        else:
            for feat in feats:
                syn_feats.append(f"N({fn}({feat}))")
    
    return syn_feats

# %%
features = df.index.values

# %%
features
# Out:
# array(['amount', 'volume', 'low', 'open', 'change', 'high', 'close',
#        'return', 'VWAP', '10_MA', '10_EMA', '10_SMA', '10_RSI'],
#       dtype=object)

# %%
syn_feats = generate_syn_feats(
    features,
    ["ts_corr", "ts_cov", "ts_stdev", "ts_zscore", "ts_return", "ts_decaylinear"]
)

# %%
syn_feats
# Out:
# ['N(ts_corr(amount,volume))',
#  'N(ts_corr(amount,low))',
#  'N(ts_corr(amount,open))',
#  'N(ts_corr(amount,change))',
#  'N(ts_corr(amount,high))',
#  'N(ts_corr(amount,close))',
#  'N(ts_corr(amount,return))',
#  'N(ts_corr(amount,VWAP))',
#  'N(ts_corr(amount,10_MA))',
#  'N(ts_corr(amount,10_EMA))',
#  'N(ts_corr(amount,10_SMA))',
#  'N(ts_corr(amount,10_RSI))',
#  'N(ts_corr(volume,low))',
#  'N(ts_corr(volume,open))',
#  'N(ts_corr(volume,change))',
#  'N(ts_corr(volume,high))',
#  'N(ts_corr(volume,close))',
#  'N(ts_corr(volume,return))',
#  'N(ts_corr(volume,VWAP))',
#  'N(ts_corr(volume,10_MA))',
#  'N(ts_corr(volume,10_EMA))',
#  'N(ts_corr(volume,10_SMA))',
#  'N(ts_corr(volume,10_RSI))',
#  'N(ts_corr(low,open))',
#  'N(ts_corr(low,change))',
#  'N(ts_corr(low,high))',
#  'N(ts_corr(low,close))',
#  'N(ts_corr(low,return))',
#  'N(ts_corr(low,VWAP))',
#  'N(ts_corr(low,10_MA))',
#  'N(ts_corr(low,10_EMA))',
#  'N(ts_corr(low,10_SMA))',
#  'N(ts_corr(low,10_RSI))',
#  'N(ts_corr(open,change))',
#  'N(ts_corr(open,high))',
#  'N(ts_corr(open,close))',
#  'N(ts_corr(open,return))',
#  'N(ts_corr(open,VWAP))',
#  'N(ts_corr(open,10_MA))',
#  'N(ts_corr(open,10_EMA))',
#  'N(ts_corr(open,10_SMA))',
#  'N(ts_corr(open,10_RSI))',
#  'N(ts_corr(change,high))',
#  'N(ts_corr(change,close))',
#  'N(ts_corr(change,return))',
#  'N(ts_corr(change,VWAP))',
#  'N(ts_corr(change,10_MA))',
#  'N(ts_corr(change,10_EMA))',
#  'N(ts_corr(change,10_SMA))',
#  'N(ts_corr(change,10_RSI))',
#  'N(ts_corr(high,close))',
#  'N(ts_corr(high,return))',
#  'N(ts_corr(high,VWAP))',
#  'N(ts_corr(high,10_MA))',
#  'N(ts_corr(high,10_EMA))',
#  'N(ts_corr(high,10_SMA))',
#  'N(ts_corr(high,10_RSI))',
#  'N(ts_corr(close,return))',
#  'N(ts_corr(close,VWAP))',
#  'N(ts_corr(close,10_MA))',
#  'N(ts_corr(close,10_EMA))',
#  'N(ts_corr(close,10_SMA))',
#  'N(ts_corr(close,10_RSI))',
#  'N(ts_corr(return,VWAP))',
#  'N(ts_corr(return,10_MA))',
#  'N(ts_corr(return,10_EMA))',
#  'N(ts_corr(return,10_SMA))',
#  'N(ts_corr(return,10_RSI))',
#  'N(ts_corr(VWAP,10_MA))',
#  'N(ts_corr(VWAP,10_EMA))',
#  'N(ts_corr(VWAP,10_SMA))',
#  'N(ts_corr(VWAP,10_RSI))',
#  'N(ts_corr(10_MA,10_EMA))',
#  'N(ts_corr(10_MA,10_SMA))',
#  'N(ts_corr(10_MA,10_RSI))',
#  'N(ts_corr(10_EMA,10_SMA))',
#  'N(ts_corr(10_EMA,10_RSI))',
#  'N(ts_corr(10_SMA,10_RSI))',
#  'N(ts_cov(amount,volume))',
#  'N(ts_cov(amount,low))',
#  'N(ts_cov(amount,open))',
#  'N(ts_cov(amount,change))',
#  'N(ts_cov(amount,high))',
#  'N(ts_cov(amount,close))',
#  'N(ts_cov(amount,return))',
#  'N(ts_cov(amount,VWAP))',
#  'N(ts_cov(amount,10_MA))',
#  'N(ts_cov(amount,10_EMA))',
#  'N(ts_cov(amount,10_SMA))',
#  'N(ts_cov(amount,10_RSI))',
#  'N(ts_cov(volume,low))',
#  'N(ts_cov(volume,open))',
#  'N(ts_cov(volume,change))',
#  'N(ts_cov(volume,high))',
#  'N(ts_cov(volume,close))',
#  'N(ts_cov(volume,return))',
#  'N(ts_cov(volume,VWAP))',
#  'N(ts_cov(volume,10_MA))',
#  'N(ts_cov(volume,10_EMA))',
#  'N(ts_cov(volume,10_SMA))',
#  'N(ts_cov(volume,10_RSI))',
#  'N(ts_cov(low,open))',
#  'N(ts_cov(low,change))',
#  'N(ts_cov(low,high))',
#  'N(ts_cov(low,close))',
#  'N(ts_cov(low,return))',
#  'N(ts_cov(low,VWAP))',
#  'N(ts_cov(low,10_MA))',
#  'N(ts_cov(low,10_EMA))',
#  'N(ts_cov(low,10_SMA))',
#  'N(ts_cov(low,10_RSI))',
#  'N(ts_cov(open,change))',
#  'N(ts_cov(open,high))',
#  'N(ts_cov(open,close))',
#  'N(ts_cov(open,return))',
#  'N(ts_cov(open,VWAP))',
#  'N(ts_cov(open,10_MA))',
#  'N(ts_cov(open,10_EMA))',
#  'N(ts_cov(open,10_SMA))',
#  'N(ts_cov(open,10_RSI))',
#  'N(ts_cov(change,high))',
#  'N(ts_cov(change,close))',
#  'N(ts_cov(change,return))',
#  'N(ts_cov(change,VWAP))',
#  'N(ts_cov(change,10_MA))',
#  'N(ts_cov(change,10_EMA))',
#  'N(ts_cov(change,10_SMA))',
#  'N(ts_cov(change,10_RSI))',
#  'N(ts_cov(high,close))',
#  'N(ts_cov(high,return))',
#  'N(ts_cov(high,VWAP))',
#  'N(ts_cov(high,10_MA))',
#  'N(ts_cov(high,10_EMA))',
#  'N(ts_cov(high,10_SMA))',
#  'N(ts_cov(high,10_RSI))',
#  'N(ts_cov(close,return))',
#  'N(ts_cov(close,VWAP))',
#  'N(ts_cov(close,10_MA))',
#  'N(ts_cov(close,10_EMA))',
#  'N(ts_cov(close,10_SMA))',
#  'N(ts_cov(close,10_RSI))',
#  'N(ts_cov(return,VWAP))',
#  'N(ts_cov(return,10_MA))',
#  'N(ts_cov(return,10_EMA))',
#  'N(ts_cov(return,10_SMA))',
#  'N(ts_cov(return,10_RSI))',
#  'N(ts_cov(VWAP,10_MA))',
#  'N(ts_cov(VWAP,10_EMA))',
#  'N(ts_cov(VWAP,10_SMA))',
#  'N(ts_cov(VWAP,10_RSI))',
#  'N(ts_cov(10_MA,10_EMA))',
#  'N(ts_cov(10_MA,10_SMA))',
#  'N(ts_cov(10_MA,10_RSI))',
#  'N(ts_cov(10_EMA,10_SMA))',
#  'N(ts_cov(10_EMA,10_RSI))',
#  'N(ts_cov(10_SMA,10_RSI))',
#  'N(ts_stdev(amount))',
#  'N(ts_stdev(volume))',
#  'N(ts_stdev(low))',
#  'N(ts_stdev(open))',
#  'N(ts_stdev(change))',
#  'N(ts_stdev(high))',
#  'N(ts_stdev(close))',
#  'N(ts_stdev(return))',
#  'N(ts_stdev(VWAP))',
#  'N(ts_stdev(10_MA))',
#  'N(ts_stdev(10_EMA))',
#  'N(ts_stdev(10_SMA))',
#  'N(ts_stdev(10_RSI))',
#  'N(ts_zscore(amount))',
#  'N(ts_zscore(volume))',
#  'N(ts_zscore(low))',
#  'N(ts_zscore(open))',
#  'N(ts_zscore(change))',
#  'N(ts_zscore(high))',
#  'N(ts_zscore(close))',
#  'N(ts_zscore(return))',
#  'N(ts_zscore(VWAP))',
#  'N(ts_zscore(10_MA))',
#  'N(ts_zscore(10_EMA))',
#  'N(ts_zscore(10_SMA))',
#  'N(ts_zscore(10_RSI))',
#  'N(ts_return(amount))',
#  'N(ts_return(volume))',
#  'N(ts_return(low))',
#  'N(ts_return(open))',
#  'N(ts_return(change))',
#  'N(ts_return(high))',
#  'N(ts_return(close))',
#  'N(ts_return(return))',
#  'N(ts_return(VWAP))',
#  'N(ts_return(10_MA))',
#  'N(ts_return(10_EMA))',
#  'N(ts_return(10_SMA))',
#  'N(ts_return(10_RSI))',
#  'N(ts_decaylinear(amount))',
#  'N(ts_decaylinear(volume))',
#  'N(ts_decaylinear(low))',
#  'N(ts_decaylinear(open))',
#  'N(ts_decaylinear(change))',
#  'N(ts_decaylinear(high))',
#  'N(ts_decaylinear(close))',
#  'N(ts_decaylinear(return))',
#  'N(ts_decaylinear(VWAP))',
#  'N(ts_decaylinear(10_MA))',
#  'N(ts_decaylinear(10_EMA))',
#  'N(ts_decaylinear(10_SMA))',
#  'N(ts_decaylinear(10_RSI))']

# %%
# original program may genreate nan value when take corr between RSI and any other features if RSI is all 100 for that perios
# this situation happened around 2018 when the index futures price keep increasing for half a month
# according to the definision of RSI, it will result RSI to be maintained at 100 for several days.
# if we accidentally hit that period and use an array of all 100 to calculate corr, result will be nan

# %%
train_data = np.array(samples[:1000], dtype='float32')
test_data = np.array(samples[1000:], dtype='float32')
train_targets = np.array(targets[:1000], dtype='float32')
test_targets = np.array(targets[1000:], dtype='float32')

# %%
# we can see that originally only samples from 957 to 975 has null value inside
# after we change the code, we got non null values

# %%
def clean_array(t1):
    for i in range(len(t1)):  # 遍历每一行
        temp_row = t1[i]  # 当前的一行
        finite_num = np.sum(np.isfinite(temp_row))
        if finite_num != len(temp_row):  
            temp_not_infnull_row = temp_row[np.isfinite(temp_row)]
            #temp_not_nan_row = temp_row[temp_row == temp_row]  # 去掉nan的ndarray
            sub = temp_not_infnull_row.max()
            temp_row[np.isnan(temp_row)] = sub
            temp_row[np.isinf(temp_row)] = sub
    return t1

def generate_syn_samples(train_data, test_data, width=2, strides=1):
    feomap = { 'train': [], 'test': [] }
    fefns = (ts_corr, ts_cov, ts_stdev, ts_zscore, ts_return, ts_decaylinear)
    nfeats = train_data[0].shape[0]
    
    for sample in train_data:
        feoutput = []
        
        for fefn in fefns:
            if fefn in [ts_corr, ts_cov]:
                for r1, r2 in combinations(range(nfeats), 2):
                    res = fefn(sample[r1], sample[r2], d=width, s=strides)                
                    feoutput.append(res)
            else:
                for row in sample:
                    res = fefn(row, d=width, s=strides)
                    feoutput.append(res)
        feoutput = clean_array(feoutput)            
        feomap['train'].append(feoutput)
    print('train_done')   
    for sample in test_data:
        feoutput = []
        
        for fefn in fefns:
            if fefn in [ts_corr, ts_cov]:
                for r1, r2 in combinations(range(nfeats), 2):
                    res = fefn(sample[r1], sample[r2], d=width, s=strides)                  
                    feoutput.append(res)
            else:
                for row in sample:
                    res = fefn(row, d=width, s=strides)
                    feoutput.append(res)
        feoutput = clean_array(feoutput)  
        feomap['test'].append(feoutput)
    print('test_done')
    
    feomap['train'] = np.array(feomap['train'], dtype='float32')
    feomap['test'] = np.array(feomap['test'], dtype='float32')
    
    print(feomap['train'])
    print(feomap['test'])
    
    # Normalize
    nrows, ncols = feomap['train'][0].shape
    
    for i in range(nrows):
        for j in range(ncols):
            arr = []
            
            for sample in feomap['train']:
                arr.append(sample[i,j])
                
            arr_mean = np.mean(arr)
            arr_stdev = np.std(arr)
            
            for sample in feomap['train']:
                sample[i,j] = (sample[i,j] - arr_mean) / arr_stdev
                
            for sample in feomap['test']:
                sample[i,j] = (sample[i,j] - arr_mean) / arr_stdev

    return feomap

# %%
syn_samples_dict = generate_syn_samples(train_data, test_data, width=10, strides=3)
# Out:
# divide by zero encountered in float_scalars
# invalid value encountered in true_divide
# invalid value encountered in true_divide
# divide by zero encountered in float_scalars
# train_done
# test_done
# [[[ 9.22527075e-01  9.32895720e-01  9.44120467e-01 ...  9.93889153e-01
#     9.89142299e-01  9.94122088e-01]
#   [-2.08740845e-01 -2.29130000e-01 -6.17094943e-03 ... -5.05093396e-01
#     1.43848822e-01  4.44946826e-01]
#   [-8.94890651e-02 -1.85409501e-01  1.59743756e-01 ... -5.41329645e-02
#     4.02445644e-01  4.85285997e-01]
#   ...
#   [ 2.27476440e+03  2.26222119e+03  2.24979810e+03 ...  2.25074536e+03
#     2.28084912e+03  2.32618677e+03]
#   [ 2.27778833e+03  2.26606226e+03  2.25210107e+03 ...  2.24700366e+03
#     2.27159180e+03  2.30987915e+03]
#   [ 5.27983742e+01  6.10389633e+01  4.49969521e+01 ...  2.86707478e+01
#     2.48872528e+01  2.65176811e+01]]
#
#  [[ 9.87651825e-01  9.13489521e-01  9.36153650e-01 ...  9.92388248e-01
#     9.93395865e-01  9.78216648e-01]
#   [-2.46351108e-01 -2.20788136e-01 -1.77538544e-01 ... -4.85538125e-01
#    -3.51534903e-01 -1.59451105e-02]
#   [-1.49121955e-01 -1.36270344e-01 -1.08581506e-01 ... -2.78065294e-01
#     1.86142474e-01  2.67822593e-01]
#   ...
#   [ 2.28051489e+03  2.27176831e+03  2.25719604e+03 ...  2.24544751e+03
#     2.25787451e+03  2.29465698e+03]
#   [ 2.28188110e+03  2.27590674e+03  2.26020923e+03 ...  2.24612793e+03
#     2.25193115e+03  2.28310791e+03]
#   [ 6.18028984e+01  5.97073555e+01  5.83252182e+01 ...  3.79524879e+01
#     2.45185318e+01  2.72281017e+01]]
#
#  [[ 9.67785895e-01  9.87592936e-01  9.15522039e-01 ...  8.61122608e-01
#     9.94130850e-01  9.93877947e-01]
#   [ 2.82664061e-01 -8.76550376e-02 -2.67686278e-01 ... -3.39944422e-01
#    -5.67484498e-01 -5.96047156e-02]
#   [ 4.20293063e-01 -5.04229143e-02 -1.83487147e-01 ...  4.47267108e-03
#    -1.95791066e-01  3.54615778e-01]
#   ...
#   [ 2.28543750e+03  2.27748291e+03  2.26770483e+03 ...  2.24678467e+03
#     2.24656982e+03  2.26825366e+03]
#   [ 2.28643506e+03  2.27933374e+03  2.27231543e+03 ...  2.24928320e+03
#     2.24508594e+03  2.26067065e+03]
#   [ 6.23087540e+01  5.68137970e+01  6.49786301e+01 ...  4.49850998e+01
#     2.94603443e+01  2.31080990e+01]]
#
#  ...
#
#  [[ 9.60968792e-01  9.70041215e-01  9.01998580e-01 ...  7.47295797e-01
#     9.73654509e-01  9.73543465e-01]
#   [-6.86177164e-02 -2.95869052e-01 -5.54722309e-01 ... -3.80288392e-01
#    -3.67076278e-01  1.75429165e-01]
#   [-3.35550725e-01 -4.28083360e-01 -4.87870276e-01 ... -1.69609830e-01
#    -3.20169866e-01  1.59348011e-01]
#   ...
#   [ 2.71428345e+03  2.69599951e+03  2.67782422e+03 ...  2.67910693e+03
#     2.69132031e+03  2.70980005e+03]
#   [ 2.71810156e+03  2.70309814e+03  2.68140942e+03 ...  2.67768774e+03
#     2.68777856e+03  2.70188379e+03]
#   [ 6.63346710e+01  6.19434700e+01  4.93249016e+01 ...  4.03932266e+01
#     4.12952690e+01  4.70106239e+01]]
#
#  [[ 9.22621965e-01  9.68197346e-01  9.71114516e-01 ...  7.67444253e-01
#     7.45976925e-01  9.74810421e-01]
#   [ 5.42574406e-01 -4.26355273e-01 -3.23409677e-01 ... -3.19436312e-01
#    -3.95477682e-01 -3.71290624e-01]
#   [ 3.10497999e-01 -5.75547636e-01 -4.37837660e-01 ... -1.35657012e-01
#    -2.16466755e-01 -2.94149756e-01]
#   ...
#   [ 2.72336841e+03  2.70870435e+03  2.68849854e+03 ...  2.67373779e+03
#     2.68263184e+03  2.69621094e+03]
#   [ 2.72549756e+03  2.71370532e+03  2.69467871e+03 ...  2.67211548e+03
#     2.68124976e+03  2.69026367e+03]
#   [ 6.42470856e+01  6.18192368e+01  5.58908157e+01 ...  4.13073807e+01
#     3.52148552e+01  4.29684868e+01]]
#
#  [[ 9.28443074e-01  9.29455280e-01  9.74122584e-01 ...  8.36774886e-01
#     7.79688537e-01  7.49680340e-01]
#   [ 7.58187115e-01  7.67775774e-01 -2.45417207e-01 ... -3.69005024e-01
#    -3.11256260e-01 -3.49703759e-01]
#   [ 6.32856011e-01  3.88844430e-01 -4.11842495e-01 ... -3.95202309e-01
#    -9.33426172e-02 -5.52993417e-02]
#   ...
#   [ 2.72339990e+03  2.71944482e+03  2.70301245e+03 ...  2.67261035e+03
#     2.67646191e+03  2.68679614e+03]
#   [ 2.72128760e+03  2.72256445e+03  2.70972290e+03 ...  2.67250244e+03
#     2.67509863e+03  2.68487793e+03]
#   [ 5.90189857e+01  6.36027451e+01  5.77952652e+01 ...  5.41623116e+01
#     4.62149887e+01  3.69801331e+01]]]
# [[[ 9.30777013e-01  9.30261016e-01  9.60968792e-01 ...  9.01998580e-01
#     8.00538003e-01  7.47295797e-01]
#   [ 2.83689320e-01  6.74404085e-01 -6.86177164e-02 ... -5.54722309e-01
#    -1.28230244e-01 -3.80288392e-01]
#   [ 3.13996285e-01  5.02317429e-01 -3.35550725e-01 ... -4.87870276e-01
#    -5.52238375e-02 -1.69609830e-01]
#   ...
#   [ 2.71468164e+03  2.72475342e+03  2.71428345e+03 ...  2.67782422e+03
#     2.67207178e+03  2.67910693e+03]
#   [ 2.70921753e+03  2.72501831e+03  2.71810156e+03 ...  2.68140942e+03
#     2.67059155e+03  2.67768774e+03]
#   [ 4.32704697e+01  5.87631454e+01  6.63346710e+01 ...  4.93249016e+01
#     4.65959625e+01  4.03932266e+01]]
#
#  [[ 8.82263780e-01  9.13518071e-01  9.22621965e-01 ...  9.71114516e-01
#     8.96271527e-01  7.67444253e-01]
#   [-1.31933987e-01  7.01286137e-01  5.42574406e-01 ... -3.23409677e-01
#    -5.62696040e-01 -3.19436312e-01]
#   [-1.61226079e-01  6.66001081e-01  3.10497999e-01 ... -4.37837660e-01
#    -4.77330565e-01 -1.35657012e-01]
#   ...
#   [ 2.70006543e+03  2.71973071e+03  2.72336841e+03 ...  2.68849854e+03
#     2.67453784e+03  2.67373779e+03]
#   [ 2.69214893e+03  2.71555371e+03  2.72549756e+03 ...  2.69467871e+03
#     2.67630347e+03  2.67211548e+03]
#   [ 4.00529976e+01  5.14290428e+01  6.42470856e+01 ...  5.58908157e+01
#     5.22856216e+01  4.13073807e+01]]
#
#  [[ 8.29791248e-01  9.41521645e-01  9.28443074e-01 ...  9.74122584e-01
#     8.95628452e-01  8.36774886e-01]
#   [-3.39868248e-01  3.59970555e-02  7.58187115e-01 ... -2.45417207e-01
#    -4.77106929e-01 -3.69005024e-01]
#   [-3.46208721e-01  9.40976515e-02  6.32856011e-01 ... -4.11842495e-01
#    -3.94938141e-01 -3.95202309e-01]
#   ...
#   [ 2.68316626e+03  2.70855444e+03  2.72339990e+03 ...  2.70301245e+03
#     2.68221851e+03  2.67261035e+03]
#   [ 2.67590649e+03  2.70219727e+03  2.72128760e+03 ...  2.70972290e+03
#     2.68706274e+03  2.67250244e+03]
#   [ 3.56077728e+01  3.72698746e+01  5.90189857e+01 ...  5.77952652e+01
#     4.97856903e+01  5.41623116e+01]]
#
#  ...
#
#  [[ 9.27178025e-01  8.31757903e-01  7.98931837e-01 ...  8.07185948e-01
#     8.17985058e-01  9.05203342e-01]
#   [-8.12474862e-02  4.64869440e-01  1.94560707e-01 ... -6.01959378e-02
#    -1.91076659e-02 -2.92872369e-01]
#   [-6.95555210e-02  5.68313539e-01  3.91335189e-01 ...  1.19415812e-01
#    -1.65880039e-01 -3.32057744e-01]
#   ...
#   [ 3.45813232e+03  3.46056274e+03  3.48030591e+03 ...  3.48938525e+03
#     3.49471069e+03  3.51587842e+03]
#   [ 3.46197876e+03  3.45395312e+03  3.47482422e+03 ...  3.49083203e+03
#     3.49263086e+03  3.50505737e+03]
#   [ 4.48519783e+01  4.19855347e+01  4.78573723e+01 ...  3.68198929e+01
#     3.45780258e+01  4.05852470e+01]]
#
#  [[ 9.10848081e-01  9.01846945e-01  8.15134764e-01 ...  8.49647164e-01
#     8.76396835e-01  8.59770894e-01]
#   [-1.49558261e-01  1.22526295e-01  4.51337099e-01 ... -3.92941147e-01
#     2.14843526e-02 -2.03416154e-01]
#   [-2.38810405e-01  1.86525762e-01  6.25075996e-01 ...  2.50441954e-02
#     2.92116314e-01 -3.59498799e-01]
#   ...
#   [ 3.46878906e+03  3.45574048e+03  3.46745508e+03 ...  3.48978271e+03
#     3.49036157e+03  3.50017065e+03]
#   [ 3.47677197e+03  3.45549146e+03  3.46077954e+03 ...  3.49036206e+03
#     3.49175146e+03  3.49548364e+03]
#   [ 4.68068085e+01  4.68001595e+01  4.43889732e+01 ...  5.03279724e+01
#     3.88423653e+01  3.83684158e+01]]
#
#  [[ 9.76483285e-01  9.32802975e-01  8.91079783e-01 ...  8.61458480e-01
#     8.41588438e-01  8.69300306e-01]
#   [ 1.35957450e-01 -1.71925500e-01  5.70823014e-01 ... -4.69835043e-01
#    -5.75666539e-02  2.74643246e-02]
#   [-5.93871400e-02 -1.79650143e-01  6.34828687e-01 ... -9.05612633e-02
#     7.70481005e-02  2.72067338e-01]
#   ...
#   [ 3.48178906e+03  3.46243945e+03  3.45634521e+03 ...  3.48998730e+03
#     3.48878564e+03  3.49216602e+03]
#   [ 3.48827930e+03  3.46894287e+03  3.45196973e+03 ...  3.48939111e+03
#     3.48943164e+03  3.49266382e+03]
#   [ 5.54197273e+01  4.31217422e+01  4.77928963e+01 ...  4.99990463e+01
#     4.19371262e+01  3.59376335e+01]]]

# %%
pd.isnull(syn_samples_dict['train']).any()
# Out:
# False

# %%
from tensorflow.keras.utils import plot_model
from keras import models
from keras import layers

# %%
modelDNN = None

input_shape = syn_samples_dict['train'][0].shape

num_features_1 = 30
num_features_2 = 10

modelDNN = models.Sequential()
modelDNN.add(layers.Flatten(input_shape = input_shape))
modelDNN.add(layers.Dense(num_features_1, kernel_initializer='normal', activation = tf.nn.relu, name = 'dense_1'))
modelDNN.add(layers.Dense(num_features_1, kernel_initializer='normal', activation=tf.nn.relu, name="dense_2"))
modelDNN.add(layers.Dropout(0.2))
modelDNN.add(layers.Dense(num_features_2, kernel_initializer='normal', activation=tf.nn.relu, name="dense_3"))
modelDNN.add(layers.Dense(num_features_2, kernel_initializer='normal', activation=tf.nn.relu, name="dense_4"))
modelDNN.add(layers.Dropout(0.2))

modelDNN.add(layers.Dense(1, kernel_initializer='normal', activation = 'linear' ,name = "dense_head"))

modelDNN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 1456)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                43710
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                930
# _________________________________________________________________
# dropout (Dropout)            (None, 30)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                310
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                110
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# dense_head (Dense)           (None, 1)                 11
# =================================================================
# Total params: 45,071
# Trainable params: 45,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelDNN.compile(optimizer = 'rmsprop', loss = 'mse', metrics = ['mae'])
modelDNN.fit(syn_samples_dict['train'], train_targets,batch_size = 128, epochs=20, validation_data=(syn_samples_dict['test'], test_targets))
# Out:
# Epoch 1/20
# 8/8 [==============================] - 13s 78ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 9.0781e-04 - val_mae: 0.0229
# Epoch 2/20
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 9.2367e-04 - val_mae: 0.0231
# Epoch 3/20
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0011 - mae: 0.0242 - val_loss: 9.8225e-04 - val_mae: 0.0240
# Epoch 4/20
# 8/8 [==============================] - 0s 8ms/step - loss: 9.5257e-04 - mae: 0.0231 - val_loss: 0.0011 - val_mae: 0.0249
# Epoch 5/20
# 8/8 [==============================] - 0s 6ms/step - loss: 9.4704e-04 - mae: 0.0229 - val_loss: 9.2308e-04 - val_mae: 0.0233
# Epoch 6/20
# 8/8 [==============================] - 0s 6ms/step - loss: 9.4442e-04 - mae: 0.0221 - val_loss: 0.0010 - val_mae: 0.0243
# Epoch 7/20
# 8/8 [==============================] - 0s 13ms/step - loss: 7.4883e-04 - mae: 0.0205 - val_loss: 9.9999e-04 - val_mae: 0.0240
# Epoch 8/20
# 8/8 [==============================] - 0s 4ms/step - loss: 7.3169e-04 - mae: 0.0202 - val_loss: 0.0010 - val_mae: 0.0244
# Epoch 9/20
# 8/8 [==============================] - 0s 7ms/step - loss: 7.0608e-04 - mae: 0.0198 - val_loss: 0.0012 - val_mae: 0.0261
# Epoch 10/20
# 8/8 [==============================] - 0s 5ms/step - loss: 6.0548e-04 - mae: 0.0182 - val_loss: 0.0011 - val_mae: 0.0250
# Epoch 11/20
# 8/8 [==============================] - 0s 5ms/step - loss: 6.0365e-04 - mae: 0.0173 - val_loss: 0.0012 - val_mae: 0.0260
# Epoch 12/20
# 8/8 [==============================] - 0s 10ms/step - loss: 5.5855e-04 - mae: 0.0170 - val_loss: 0.0011 - val_mae: 0.0247
# Epoch 13/20
# 8/8 [==============================] - 0s 8ms/step - loss: 4.7001e-04 - mae: 0.0156 - val_loss: 0.0011 - val_mae: 0.0254
# Epoch 14/20
# 8/8 [==============================] - 0s 5ms/step - loss: 4.8383e-04 - mae: 0.0159 - val_loss: 0.0011 - val_mae: 0.0258
# Epoch 15/20
# 8/8 [==============================] - 0s 6ms/step - loss: 4.6067e-04 - mae: 0.0152 - val_loss: 0.0012 - val_mae: 0.0259
# Epoch 16/20
# 8/8 [==============================] - 0s 6ms/step - loss: 3.6759e-04 - mae: 0.0140 - val_loss: 0.0013 - val_mae: 0.0269
# Epoch 17/20
# 8/8 [==============================] - 0s 5ms/step - loss: 4.1446e-04 - mae: 0.0144 - val_loss: 0.0012 - val_mae: 0.0257
# Epoch 18/20
# 8/8 [==============================] - 0s 5ms/step - loss: 3.8134e-04 - mae: 0.0142 - val_loss: 0.0012 - val_mae: 0.0264
# Epoch 19/20
# 8/8 [==============================] - 0s 5ms/step - loss: 3.2531e-04 - mae: 0.0133 - val_loss: 0.0012 - val_mae: 0.0256
# Epoch 20/20
# 8/8 [==============================] - 0s 6ms/step - loss: 3.1023e-04 - mae: 0.0128 - val_loss: 0.0012 - val_mae: 0.0259

# %%
import shap
